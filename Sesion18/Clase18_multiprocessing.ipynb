# %% [markdown]
# # ***Análisis de Datos y Big data***
#
# ## ***Universidad de los Andes***
# >## **Dirección de Educación Continua.**
# >>## **Formación de habilidades escenciales.**
#
# ![Imágen1](https://github.com/jazaineam1/Andes_ADDBD/blob/main/Imagenes/Presentaci%C3%B3n-removebg-preview.png?raw=true)
#
#
# # ***Multiprocessing y algo más***
# # Clase 18

# %% [markdown]
# Un sitemap de una página web es básicamente un mapa o una guía que enumera todas las páginas importantes de un sitio web. Se puede ver  como un índice o tabla de contenidos que le dice a los motores de búsqueda y a los visitantes dónde está cada pieza de contenido en tu sitio. Los sitemaps son especialmente útiles para sitios web grandes, con muchas páginas, o para aquellos con contenido que no está fácilmente accesible a través de enlaces.
#
# ### Propósitos y Beneficios de un Sitemap
#
# 1. **Mejora la Indexación por Motores de Búsqueda**:
#    - Los sitemaps son una herramienta crucial para los motores de búsqueda como Google. Ayudan a los rastreadores de estos motores a encontrar y entender el contenido de tu sitio web. Cuando envías un sitemap a un motor de búsqueda, básicamente le estás diciendo: "Aquí están las páginas de mi sitio web, por favor inclúyelas en tu índice".
#
# 2. **Facilita la Navegación**:
#    - Para los visitantes del sitio, un sitemap puede actuar como una herramienta de navegación rápida, permitiéndoles encontrar la información que buscan sin tener que navegar por todo el sitio.
#
# 3. **Organización y Estructura del Sitio Web**:
#    - Crear un sitemap te obliga a pensar en la estructura y organización de tu sitio, lo cual es crucial para una buena experiencia de usuario y SEO (optimización para motores de búsqueda).
#
# 4. **Identificación de URLs y Contenido**:
#    - Los sitemaps permiten a los motores de búsqueda identificar rápidamente las URLs de tu sitio y cualquier contenido actualizado, lo cual es esencial para sitios con contenido que cambia frecuentemente.
#
# ### Tipos de Sitemaps
#
# 1. **Sitemap XML**:
#    - Es el tipo más común de sitemap. Está formateado de manera que los motores de búsqueda pueden leer e interpretar fácilmente el archivo. Los sitemaps XML listan las URLs de un sitio y pueden incluir información adicional como la última fecha de actualización, la frecuencia de cambios y la importancia de las URLs.
#
#       revisa el [enlace](https://www.eltiempo.com/robots.txt)
#
#
# 2. **Sitemaps de Imágenes y Vídeos**:
#    - Para sitios que son ricos en contenido multimedia, puedes tener sitemaps específicos que ayudan a los motores de búsqueda a encontrar tus imágenes y videos más fácilmente.
#
#    revisa el [enlace](https://www.youtube.com/feeds/videos.xml?channel_id=UCw7Bz6EHxlnOoBUBlJZCWCw)

# %% [markdown]
# Revisa el sitemap [https://www.youtube.com/sitemaps/sitemap.xml](https://www.youtube.com/sitemaps/sitemap.xml) y trata de leer la información relacionada a la primer noticia que encuentres usando lenguaje python

# %%
import requests
from bs4 import BeautifulSoup

# URL del artículo
url = 'https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931'

# Realizar la solicitud HTTP para obtener el contenido de la página
respuesta = requests.get(url)

# Parsear el contenido HTML con BeautifulSoup
soup = BeautifulSoup(respuesta.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Mario Sabato habla de Nairo Quintana, Egan Bernal y Rigoberto Uran en Colombia</title>
# <link href="https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931" rel="canonical"/>
# <meta content="index, follow, max-image-preview:large" name="robots">
# <meta content="index, follow" name="GOOGLEBOT">
# <meta content="index, follow" name="bingbot"/>
# <meta content="Mario Sabato, Nairo Quintana" name="keywords"/>
# <meta content="Mario Sabato, Nairo Quintana" name="news_keywords"/>
# <meta content="El narrador argentino Mario Sabato habla de los ciclistas colombianos Nairo Quintana, Egan Bernal y Rigoberto Urán." name="description"/>
# <meta content="865245646889167" property="fb:app_id">
# <meta content="telephone=no" name="format-detection">
# <meta content="Andrés Felipe Balaguera Sarmiento" name="author">
# <meta content="News" name="genre"/>
# <meta content="Colombia" name="geo.placename"/>
# <meta content="4.570868;-74.297333" name="geo.position"/>
# <meta content="CO" name="geo.region"/>
# <meta content="notranslate" name="google"/>
# <meta content="4.570868, -74.297333" name="ICBM"/>
# <meta content="spanish" name="language"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@ELTIEMPO" name="twitter:site"/>
# <meta content="@ELTIEMPO" name="twitter:creator"/>
# <meta content="Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida'" name="twitter:title"/>
# <meta content="El narrador argentino Mario Sabato habla de los ciclistas colombianos Nairo Quintana, Egan Bernal y Rigoberto Urán." property="twitter:description"/>
# <meta content="0" name="twitter:image"/>
# <meta content="Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida'" property="og:title"/>
# <meta content="https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931" property="og:url"/>
# <meta content="El Tiempo" property="og:site_name"/>
# <meta content="100002279652972" property="fb:admins"/>
# <meta content="es_CO" property="og:locale"/>
# <meta content="es_CO" property="og:locale:alternate"/>
# <meta content="El narrador argentino Mario Sabato habla de los ciclistas colombianos Nairo Quintana, Egan Bernal y Rigoberto Urán." property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="0" property="og:image"/>
# <meta content="0" property="og:image:url"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="675" property="og:image:height"/>
# <meta content="" property="og:image:type"/>
# <meta content="2024-01-26T23:10:00-05:00" property="article:published_time"/>
# <meta content="2024-01-27T00:00:00-05:00" property="article:modified_time"/>
# <meta content="2024-01-26T23:10:00-05:00" property="date"/>
# <meta content="2024-01-26T23:10:00-05:00" property="DC.date.issued"/>
# <meta content="Andrés Felipe Balaguera Sarmiento" property="article:author"/>
# <meta content="Ciclismo" property="article:section"/>
# <link href="https://www.eltiempo.com/rss/deportes_ciclismo.xml" rel="alternate" title="Rss de Ciclismo" type="application/rss+xml">
# <link as="font" crossorigin="" href="/assets/7b6661f32c6048581be8.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/709ab92879359de5d7f6.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/a1535f451fb7bb98f526.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/b8d62943d0a753a0e028.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/7ef3bbc98d285227e83a.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/b245bc85ddeedb27a549.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/185f6b038323b60834d2.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/assets/227c93190fe7f82de3f8.woff2" rel="preload" type="font/woff2"/>
# <meta content="Mario Sabato" property="article:tag"/>
# <meta content="Contenidolibre" property="article:tag"/>
# <meta content="Ciclistas colombianos" property="article:tag"/>
# <meta content="Egan Bernal" property="article:tag"/>
# <meta content="Nairo Quintana" property="article:tag"/>
# <meta content="TagsContenido:Mario Sabato;TagsContenido:Contenidolibre;TagsContenido:Ciclistas colombianos;TagsContenido:Egan Bernal;TagsContenido:Nairo Quintana" property="mrf:tags"/>
# <meta content="CategoriaContenido:Premium;TipoContenido:Articulo;RedactorContenido:Andrés Felipe Balaguera Sarmiento;SeccionContenido:Deportes;SubseccionContenido:Ciclismo" property="mrf:tags"/>
# <link href="https://www.eltiempo.com/assets/default_css.b7013c438f44d6b35160.css?1717712399" rel="stylesheet" type="text/css">
# <link href="/favicon.ico" rel="shortcut icon">
# <link href="/favicon-32x32.png" rel="apple-touch-icon" sizes="32x32"/>
# <link href="/favicon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/favicon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link as="image" href="https://www.eltiempo.com/images/eltiempo_logo.png?1717712399" rel="preload"/>
# <!-- Google Tag Manager Contenedor 1-->
# <script>
#
#     var ID_GTM1 = 'GTM-WG4KTGL';
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer',ID_GTM1);
#
# </script>
# <!-- End Google Tag Manager -->
# <!-- Google Tag Manager Contenedor 2 -->
# <script>
#
#     var ID_GTM2 = 'GTM-PLVTDKZ';
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer',ID_GTM2);
#
# </script>
# <!-- End Google Tag Manager -->
# <!-- Tealium -->
# <script async="" src="https://tags.tiqcdn.com/utag/adl/ceet/prod/utag.js" type="text/javascript"></script>
# <script src="https://tags.tiqcdn.com/utag/adl/ceet/prod/utag.sync.js"></script>
# <script type="text/javascript">
#   function logEvent(name, params) {
#     if (!name) {
#       return;
#     }
#     if (window.AnalyticsWebInterface) {
#       // Call Android interface
#       window.AnalyticsWebInterface.logEvent(name, JSON.stringify(params));
#     } else if (window.webkit
#         && window.webkit.messageHandlers
#         && window.webkit.messageHandlers.firebase) {
#       // Call iOS interface
#       var message = {
#         command: 'logEvent',
#         name: name,
#         parameters: params
#       };
#       window.webkit.messageHandlers.firebase.postMessage(message);
#     } else {
#       // No Android or iOS interface found
#       console.log("No native APIs found.");
#     }
#   }
#   function setUserProperty(name, value) {
#     if (!name || !value) {
#       return;
#     }
#     if (window.AnalyticsWebInterface) {
#       // Call Android interface
#       window.AnalyticsWebInterface.setUserProperty(name, value);
#     } else if (window.webkit
#         && window.webkit.messageHandlers
#         && window.webkit.messageHandlers.firebase) {
#       // Call iOS interface
#       var message = {
#         command: 'setUserProperty',
#         name: name,
#         value: value
#     };
#       window.webkit.messageHandlers.firebase.postMessage(message);
#     } else {
#       // No Android or iOS interface found
#       console.log("No native APIs found.");
#     }
#   }
# </script>
# <script async="" src="https://accounts.google.com/gsi/client"></script>
# <!-- Begin comScore Tag -->
# <script>
# var _comscore = _comscore || [];
# _comscore.push({
# c1: "2", c2: "6035169",
# options: {
# enableFirstPartyCookie: true,
# bypassUserConsentRequirementFor1PCookie: true
# }
# });
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# s.src = "https://sb.scorecardresearch.com/cs/6035169/beacon.js";
# el.parentNode.insertBefore(s, el);
# })();
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6035169&amp;cs_ucfr=1&amp;cv=3.9.1&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <script type="text/javascript">
# var mrfTech = 0;
# let paramsMrf = new URLSearchParams(window.location.search);
# if (paramsMrf.has("webview") || localStorage.getItem('webview') === "webview") {
# mrfTech = 4;
# }
# if (paramsMrf.has("webview-ios") || localStorage.getItem('webview') === "webview-ios") {
# mrfTech = 3;
# }
# function e(e){var t=!(arguments.length>1&&void 0!==arguments[1])||arguments[1],c=document.createElement("script");c.src=e,t?c.type="module":(c.async=!0,c.type="text/javascript",c.setAttribute("nomodule",""));var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(c,n)}function t(t,c,n){var a,o,r;null!==(a=t.marfeel)&&void 0!==a||(t.marfeel={}),null!==(o=(r=t.marfeel).cmd)&&void 0!==o||(r.cmd=[]),t.marfeel.config=n,t.marfeel.config.accountId=c;var i="https://sdk.mrf.io/statics";e("".concat(i,"/marfeel-sdk.js?id=").concat(c),!0),e("".concat(i,"/marfeel-sdk.es5.js?id=").concat(c),!1)}!function(e,c){var n=arguments.length>2&&void 0!==arguments[2]?arguments[2]:{};t(e,c,n)}(window,1645,{pageType:mrfTech} /*config*/);
# </script>
# <script async="" id="ebx" src="//applets.ebxcdn.com/ebx.js"></script>
# <script type="text/javascript">
#     ! function (f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function () {
#             n.callMethod ?
#                 n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s)
#     }
#         (window, document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '2639268933010768');
#     fbq('track', 'PageView');
# </script>
# <script>
#     var permutiveAddon ={}
# </script>
# <script>
#     document.addEventListener("DOMContentLoaded", function () {
#         const cookiePopup = document.querySelector('.c-popup');
#         const acceptCookiesButton = document.querySelector('.c-popup__button');
#         // Obtener cookies existentes (si las hay)
#         const cookiesInfoString = document.cookie.split('; ').find(row => row.startsWith('cookies-info='));
#         const cookiesInfo = cookiesInfoString ? JSON.parse(cookiesInfoString.split('=')[1]) : null;
#         const now = new Date();
#
#         // Verifica si la cookie de aceptación ya está establecida
#         if (!cookiesInfo && cookiePopup) {
#             cookiePopup.style.display = 'block';
#         }
#
#         if (cookiePopup && acceptCookiesButton) {
#             acceptCookiesButton.addEventListener('click', function() {
#                 dataLayer.push({'event':'aceptacion_cookies'});
#
#                 cookiePopup.style.display = 'none';
#                 const expiration = new Date(now.getTime() + 90 * 24 * 60 * 60 * 1000); // 90 días en milisegundos
#                 const cookieInfo = {
#                     accepted: true,
#                     expiration: expiration
#                 };
#                 document.cookie = `cookies-info=${JSON.stringify(cookieInfo)}; expires=${expiration.toUTCString()}; path=/`; // Especificar la ruta
#             });
#         }
#     });
# </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <style>
#
# @media (min-width: 768px){
# .o-section--emergencias .c-article--apertura {
#     min-height: 730px;
# }
# }
# </style>
# <script type="text/javascript">
#     var ADSTAGURL = 'https://pubads.g.doubleclick.net/gampad/ads?iu=/49787872/El_Tiempo/video&description_url=https%3A%2F%2Fwww.eltiempo.com%2F&tfcd=0&npa=0&sz=400x300%7C480x70%7C480x360%7C480x361%7C640x360%7C640x480&gdfp_req=1&output=vast&env=vp&unviewed_position_start=1&impl=s&correlator='
# </script>
# <script async="async" src="//imasdk.googleapis.com/js/sdkloader/ima3.js"></script>
# <script async="async" src="https://www.youtube.com/iframe_api?ima=1"></script>
# <script defer="defer" type="text/javascript">
#         // Variable only for piano, AVOID USE IT - Variable solo para piano - evitar usarla.
#         window.identity = null;
#
#         var textChars = 'Por favor no ingreses más de {0} caracteres.';
#         var textSpecialChars = 'No se permiten caracteres especiales.';
#         var textSpecialChars2 = 'Solo se permiten letras, números, comas, puntos y espacios en blanco.';
#         var textNumbers = 'No se permiten números.';
#         var textCharacters = 'Solo se permiten números.';
#         var textEmail = 'Este no es un correo electrónico válido.';
#         var textStartsWithZero = 'El número no puede empezar con cero.';
#         var textOnlyLettersAndNumbersNotWhiteSpaces = 'Solo se permiten letras y números sin espacios en blanco.';
#         var textOnlyLettersAndNumbersWithWhiteSpaces = 'Solo se permiten letras y números con espacios en blanco.';
#         var nameRules = {"required":true,"minlength":1,"maxlength":100,"onlyLettersAndNumbersWithWhiteSpaces":true};
#         var userRules = {"required":true,"noCharacters":true,"minlength":6,"maxlength":20};
#         var emailRules = {"required":true,"email":true,"noEmail":true,"minlength":1,"maxlength":100};
#         var phoneNumberRules = {"required":true,"noCharacters":true,"maxlength":10,"minlength":7,"noStartsWithZero":true};
#         var messageRules = {"noSpecialChars2":true,"required":true,"minlength":10,"maxlength":1000};
#         var privacyRules = {"required":true};
#         var privacyPolicyRules = {"required":true};
#         var messageRules2 = {"required":false,"maxlength":150};
#         var nameMessage = {"required":"Debes ingresar tu nombre. Recuerda que \u00e9ste no puede tener n\u00fameros o caracteres especiales.","minlength":"\u00a1Al menos debes ingresar {0} caracteres!"};
#         var emailMessage = {"required":"Ingresa tu correo electr\u00f3nico para continuar. Recuerda que debe estar bien escrito para poder continuar.","email":"Tu correo electr\u00f3nico debe tener un formato como nombre@dominio.com"};
#         var messageMessage = {"required":"Escribe ac\u00e1 el error que encontraste para que podamos revisarlo. Gracias.","maxlength":"Por favor no ingreses m\u00e1s de {0} caracteres.","minlength":"Por favor ingresa m\u00e1s de {0} caracteres."};
#         var nc = '4563da6f176be58ebd5c29ac27bdefe6';
#         var s_account = "eltiempo";
#         const PUBLIC_URL = "https://www.eltiempo.com";
#
#                                                 // Login seg
#         const SSO_MY_SUSCRIPTION_PATH = 'https://www.eltiempo.com/zona-usuario/mi-suscripcion';
#         const SSO_SUSCRIBIRME_PATH = 'https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital?utm_source=Autopauta&utm_medium=eltiempo_prp&utm_campaign=AutoPautaFija&utm_content=BotonHomeHeader';
#         const SSO_SUSCRIBIRME_DIGITAL_PATH = 'https://www.eltiempo.com/suscripcion-digital';
#         const SSO_VERIFY = 'server/verify-login/';
#         const SSO_VERIFY_COMPLEMENT = '/code/basic/';
#         const LFTIGNITER_NUMBER = '8';
#         const SSO_PROTOCOL = 'https'
#         const SSO_PORTAL = 'seg.eltiempo.com'
#         const SSO_CLIENT_ID = 'eltiempodigital';
#         const SSO_LOGOUT = 'https://seg.eltiempo.com/server/logout/eltiempodigital'
#         const DELETE_ACCOUNT = 'https://eltiempo.zendesk.com/hc/es-419/requests/new'
#         const SUBSCRIBER_TYPES = {"IG":"suscriptor-impreso","DS":{"BASICO":"suscriptor-digital","PREMIUM":"suscriptor-digital-pro"}}
#         const PASALAPAGINAURLS = {"BASICO":{"urlPasaLaPagina":"https:\/\/pasalapagina.com\/home-eltiempobasico.html"},"PREMIUM":{"urlPasaLaPagina":"https:\/\/pasalapagina.com\/home-eltiempopro.html"}}
#
#         //Variables para dmp
#         var deviceXalok = 'desktop';
#         var dmpCampaigns = {"segmento1":{"audiencia":355181,"campana":304553,"numero_campana":1,"hash":"Aa9K0aK0I1E0jwPuSnixSiUG7Uxb2DfS5AlAvRbmNC8%3D","secciones":["justicia","politica","bogota","opinion","colombia","tecnosfera"]},"segmento2":{"audiencia":355189,"campana":304554,"numero_campana":2,"hash":"Q5PKJWzAM3qixYEd2AEFSIFzg8dHRrwZff%2BPSqJJbyI%3D","secciones":["politica","vida","justicia","economia","mundo","deportes"]},"segmento3":{"audiencia":355191,"campana":303509,"numero_campana":3,"hash":"hUyTg2Ik%2B0CX3ltsRahcS4S9wt3vKgqRbyzE2oaAAP8%3D","secciones":["justicia","economia","vida","politica","colombia","tecnosfera"]},"segmento4":{"audiencia":361200,"campana":304559,"numero_campana":4,"hash":"hCNNmr%2FWJ%2FsVAMIlKAi0htYroKSt6HV26cm6gZpMFbE%3D","secciones":["economia","tecnosfera","vida","bogota","deportes","colombia"]},"segmento5":{"audiencia":428587,"campana":350483,"numero_campana":5,"hash":"Z4Lzm8NgVsYDnxtiC2YTGYs6DdS4WLmBIPiHD%2F2Kuw8%3D","secciones":["economia","tecnosfera","politica","justicia"]},"segmento6":{"audiencia":428909,"campana":362238,"numero_campana":6,"hash":"MBy3Ks6dLaQI5AxMkwn9fZd4yFWXD5w1zZ3c2rJlmE0%3D","secciones":["opinion"]},"segmento7":{"audiencia":428906,"campana":362237,"numero_campana":7,"hash":"%2Fim6k3vqRhcciGuGPEAYAqa2z3AZEScTL2X3NagwRNM%3D","secciones":["deportes"]},"segmento8":{"audiencia":428907,"campana":362236,"numero_campana":8,"hash":"e%2BJsjjtaMLQzrj%2BsGci12aYf5Y5IosdxvK89gVidtIs%3D","secciones":["tecnosfera"]}};
#         var dmpArticleNumber = 13;
#
#         var notifyButtonEnable = true;
#         var recommendationMotorUrl = "https://recomendador.eltiempo.com/recommendation";
#         // lazyload
#         var lazyloadDefault = '/images/1x1.png';
#         //google analitycs
#         var google_analitycs_ua = 'UA-118090425-1';
#         var google_client_id = '991609450965-1lnoaq26r0n6koi64pc3imne4ijdo51r.apps.googleusercontent.com';
#         var urlActual = new URL(window.location.href);
# var utmContentValue = urlActual.searchParams.get('utm_content');
# var arrayWords = ['LandingGiftCard', 'Landing_WinBack'];
#     </script>
# <script>
# let typeView = new URLSearchParams(window.location.search);
#             let webview = 'web';
#             if (typeView.has("webview") || localStorage.getItem('webview') === "webview") {
#                 webview = 'android';
#             }
#             if (typeView.has("webview-ios") || localStorage.getItem('webview') === "webview-ios") {
#                 webview = 'ios';
#             }
#             let userType = 'Anonimo';
#             if (localStorage.getItem("statePermutive")) {
#                 userType = localStorage.getItem("statePermutive");
#             }
#                         permutiveAddon = {
#                 "page": {
# "client": {
#                         "type": webview
#                     },
#                     "user":{
#                         "user_type": userType
#                     },
#                                         "article": {
#                         "id": "848931",
#                         "category": "Premium",
#                         "title": "Mario Sabato se confiesa en Colombia: &#039;El triunfo de Nairo Quintana me cambió la vida&#039;",
#                         "description": "El narrador argentino Mario Sabato habla de los ciclistas colombianos Nairo Quintana, Egan Bernal y Rigoberto Urán.",
#                         "authors": ["Andres Felipe Balaguera Sarmiento" ?? 'Redaccion El tiempo', "Andrés Felipe Balaguera Sarmiento"],
#                         "type": "Articulo",
#                         "tags": "Nairo Quintana,Ciclistas colombianos,Egan Bernal,Contenidolibre,Mario Sabato".replace(/(?!(C|c)suscriptor)-(?!(M|m)odal)/g, ' ').replace(/\b\w/g, match => match.toUpperCase()).split(','),
#                         "modifiedAt": "2024-01-27T00:00:00-05:00",
#                         "publishedAt": "2024-01-26T23:10:00-05:00",
#                         "url": "https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931",
#                         "section": "Deportes",
#                         "subsection": "Ciclismo",
#                         "premium": false
#                     }
#                 }
#             }
#         </script>
# <script>
#     !function(e,o,n,i){if(!e){e=e||{},window.permutive=e,e.q=[];var t=function(){return([1e7]+-1e3+-4e3+-8e3+-1e11).replace(/[018]/g,function(e){return(e^(window.crypto||window.msCrypto).getRandomValues(new Uint8Array(1))[0]&15>>e/4).toString(16)})};e.config=i||{},e.config.apiKey=o,e.config.workspaceId=n,e.config.environment=e.config.environment||"production",(window.crypto||window.msCrypto)&&(e.config.viewId=t());for(var g=["addon","identify","track","trigger","query","segment","segments","ready","on","once","user","consent"],r=0;r<g.length;r++){var w=g[r];e[w]=function(o){return function(){var n=Array.prototype.slice.call(arguments,0);e.q.push({functionName:o,arguments:n})}}(w)}}}(window.permutive,"f068aecf-95b3-423e-9e1c-8574f28e4323","5d0bb38d-5d11-422f-9df7-9b1c3bded5d7",{"consentRequired": false});
#         window.googletag=window.googletag||{},window.googletag.cmd=window.googletag.cmd||[],window.googletag.cmd.push(function(){if(0===window.googletag.pubads().getTargeting("permutive").length){var e=window.localStorage.getItem("_pdfps");window.googletag.pubads().setTargeting("permutive",e?JSON.parse(e):[]);var o=window.localStorage.getItem("permutive-id");o&&(window.googletag.pubads().setTargeting("puid",o),window.googletag.pubads().setTargeting("ptime",Date.now().toString())),window.permutive.config.viewId&&window.googletag.pubads().setTargeting("prmtvvid",window.permutive.config.viewId),window.permutive.config.workspaceId&&window.googletag.pubads().setTargeting("prmtvwid",window.permutive.config.workspaceId)}});
#
#     //SI ES UN ARTICULO VA EL SIGUIENTE METODO SI NO SERIA: permutive.addon('web', {} );
#     permutive.addon('web', permutiveAddon);
# </script>
# <script async="" src="https://5d0bb38d-5d11-422f-9df7-9b1c3bded5d7.edge.permutive.app/5d0bb38d-5d11-422f-9df7-9b1c3bded5d7-web.js"></script>
# <script>
#     //PIANO INTEGRATION
#     //You'll need to deploy a small piece of additional JavaScript on-site, alongside the standard Permutive tag. This script ensures that we are always able to listen for events emitted by Piano, even if the Permutive script loads after Piano. This snippet must be deployed before the TinyPass JavaScript tag.
#     window.__permutive = window.__permutive || {}
#     window.__permutive.pianoEvents = window.__permutive.pianoEvents || []
#     window.tp = window.tp || []
#     var events = ['loginRequired', 'showTemplate', 'showOffer', 'startCheckout', 'checkoutComplete', 'checkoutClose', 'meterActive', 'meterExpired']
#     events.forEach(function (evt) {
#     window.tp.push(['addHandler', evt, function (e) {
#         window.__permutive.pianoEvents.push({
#         name: evt,
#         e: e
#         })
#     }])
#     });
# </script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"NewsArticle","@id":"https:\/\/search.google.com\/structured-data\/testing-tool\/article-3285629","keywords":"Mario Sabato, Nairo Quintana","headline":"Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambi\u00f3 la vida'","description":"Nairo Quintana, de 1,68 metros de estatura, se agigant\u00f3 entre el 9 de mayo y el 1 de junio del 2014. El ciclista boyacense, por entonces una revelaci\u00f3n mundial tras el subcampeonato en el Tour de Francia de 2013, le dio a Colombia su segundo t\u00edtulo en una de las tres grandes, luego de la Vuelta a Espa\u00f1a que gan\u00f3 \u2018Lucho\u2019 Herrera en 1987. El pa\u00eds, lleno de emoci\u00f3n, vibr\u00f3 con el triunfo de \u2018Nairoman\u2019 en el Giro de Italia. Y lo hizo gracias al apasionado relato del hombre que ha narrado durante los \u00faltimos a\u00f1os las grandes haza\u00f1as del ciclismo colombiano: Mario Sabato.","alternativeHeadline":"","dateModified":"2024-01-27T00:00:00-0500","datePublished":"2024-01-26T23:10:00-0500","articleBody":"Nairo Quintana, de 1,68 metros de estatura, se agigant\u00f3 entre el 9 de mayo y el 1 de junio del 2014. El ciclista boyacense, por entonces una revelaci\u00f3n mundial tras el subcampeonato en el Tour de Francia de 2013, le dio a Colombia su segundo t\u00edtulo en una de las tres grandes, luego de la Vuelta a Espa\u00f1a que gan\u00f3 \u2018Lucho\u2019 Herrera en 1987. El pa\u00eds, lleno de emoci\u00f3n, vibr\u00f3 con el triunfo de \u2018Nairoman\u2019 en el Giro de Italia. Y lo hizo gracias al apasionado relato del hombre que ha narrado durante los \u00faltimos a\u00f1os las grandes haza\u00f1as del ciclismo colombiano: Mario Sabato. Argentino de nacimiento, pero colombiano por convicci\u00f3n, Sabato ha sido quien les ha dado voz a los triunfos de Egan y Nairo, los embalajes de Gaviria y Molano, los triunfos de Mariana Paj\u00f3n, las escaladas de Sergio Higuita, las luchas de Rigoberto Ur\u00e1n y los golpes sobre la mesa de Santiago Buitrago, Einer Rubio y tantos m\u00e1s. Su relato, una marca registrada durante 15 a\u00f1os en la cadena internacional ESPN, migra ahora a RCN, el canal con el que ayer debut\u00f3 en los nacionales de ciclismo y en el que espera seguir narrando las batallas de los \u2018escarabajos\u2019. La verdad que es un desaf\u00edo muy importante, es un desaf\u00edo muy grande para mi carrera venir a Colombia. Yo estuve 15 a\u00f1os en Espn y, como puse el otro d\u00eda cuando me desped\u00eda, fui muy feliz, crec\u00ed much\u00edsimo como persona y como profesional, pero, bueno, cuando me propusieron este reto era como una combinaci\u00f3n de todo lo que yo quer\u00eda hacer porque yo amo narrar las carreras internacionales, las mejores carreras del mundo, pero tambi\u00e9n ten\u00eda una deuda pendiente porque yo digo: \u2018Vengo siempre a Colombia 10, 12 veces al a\u00f1o y nunca pude narrar una carrera colombiana\u2019. S\u00ed, cuando Andrea Guerrero (gerente de Deportes en RCN) me dice: \u2018Mira, Mario, vamos a tener Giro, Tour, Vuelta, Ol\u00edmpicos, bla bla bla bla, todas las carreras del calendario internacional\u2019, dije: \u2018Buen\u00edsimo, okay, lo mismo que yo hago\u2019, y me dice: \u2018Noo, pero tambi\u00e9n vamos a tener Vuelta a Colombia, Cl\u00e1sico RCN\u2026\u2019, ah\u00ed yo digo: \u2018Ufff, qu\u00e9 interesante\u2019, porque como que yo adentro m\u00edo ten\u00eda esa deuda pendiente y, bueno, se combin\u00f3 todo de una manera perfecta y ac\u00e1 estoy como el nuevo narrador de ciclismo de RCN, que para m\u00ed es un placer muy grande. Bueno, yo tengo mi familia, mi t\u00edo Carlos Reybaud, que fue ciclista, que corri\u00f3 los Juegos Ol\u00edmpicos, que fue campe\u00f3n argentino varias veces y a ra\u00edz de seguirlo a \u00e9l, si bien nosotros en Argentina nacemos con una pelota de f\u00fatbol en la cabeza porque es as\u00ed, \u00bfeh? (risas), los s\u00e1bados eran de ir  ...
# <script type="application/ld+json">[]</script>
# <script type="application/ld+json">[]</script>
# <script type="application/ld+json">[{"@type":"VideoObject","name":"Mario Sabato se sincera: 'El triunfo de Nairo Quintana me cambi\u00f3 la vida' | El Tiempo","thumbnailUrl":"https:\/\/imagenes.eltiempo.com\/files\/image_1200_600\/uploads\/2017\/01\/02\/586a6848665d3.jpeg","description":"Mario Sabato habla sobre Nairo Quintana, Egan Bernal y otros ciclistas en entrevista con EL TIEMPO.","duration":"","uploadDate":"2024-01-26T22:37:02-0500","embedUrl":"https:\/\/www.youtube.com\/watch?v=FDUClHSt6Uo","contentUrl":"","@context":"https:\/\/schema.org"}]</script>
# <script type="application/ld+json">[{"@context":"https:\/\/schema.org","@type":"Person","name":"Andr\u00e9s Felipe Balaguera Sarmiento"}]</script>
# <script defer="defer" type="text/javascript">
#     const weekday = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'];
#     const currentDate = new Date();
#     const day = weekday[currentDate.getDay()]
#     const hour = currentDate.getHours() + ':' + (currentDate.getMinutes() < 10 ? '0' : '') + currentDate.getMinutes()+(currentDate.getHours()>= 12 ? "pm" : "am")
#     const userName = localStorage.getItem("userName");
#     let tagsArticle = 'Nairo Quintana,Ciclistas colombianos,Egan Bernal,Contenidolibre,Mario Sabato'.replace(/(?!(C|c)suscriptor)-(?!(M|m)odal)/g, ' ');
#     tagsArticle=tagsArticle.split(',');
#     const premium = tagsArticle.includes("csuscriptor-modal") || tagsArticle.includes("csuscriptor")  ? 1 : 0;
#     let tagBbc = tagsArticle.includes("bbc news");
#     tagBbc = tagBbc ? ' BBC' : '';
#     window.digitalData = {
#         page: {
#             pageID: 848931,
#             pageName: 'Ciclismo:mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931-Articulo',
#             channel: 'Ciclismo',
#             day: day,
#             hour: hour,
#             referrer: document.referrer,
#             contentType: 'Articulo' + tagBbc ,
#             userName: userName !== undefined && userName > 0 ? userName : "",
#             weekday: day,
#             section: 'Deportes',
#             subsection: 'Ciclismo',
#             autores: 'Andrés Felipe Balaguera Sarmiento',
#             dateModified: '2024-02-22',
#             datePublish: '2024-01-26',
#             datePublishIso: '2024-01-27T00:00',
#             followup: 'false',
#             alcance: 'false',
#             premium: premium,
#             bloqueo: '0',
#             tags: tagsArticle,
#             categoryType: 'Premium',
#             redactorVisible :'Andres Felipe Balaguera Sarmiento',
#             titulo: 'Mario Sabato se confiesa en Colombia: "El triunfo de Nairo Quintana me cambió la vida"',
#         }
#     };
#
#     const savedData = {
#         id: 848931,
#         titulo: 'Mario Sabato se confiesa en Colombia: "El triunfo de Nairo Quintana me cambió la vida"',
#         lead: '',
#         thumbnail: '0',
#         timestamp_creacion: '1706328600',
#         timestamp_modificacion: '1706331600',
#         url: '/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931',
#         seccion: 'Deportes',
#         subseccion: 'Ciclismo'
#     };
#     const categorySlug = 'deportes/ciclismo';
# </script>
# <script type="application/ld+json">
#         {
#             "@context":"http://schema.org",
#             "@type":"BreadcrumbList",
#             "itemListElement": [
#                 [
#                 {
#                         "@type":"ListItem",
#                         "position":"1",
#                 "item":{
#                     "@id":"https://www.eltiempo.com",
#                     "name":"Inicio"
#                 }
#             },
#                     {
#                 "@type":"ListItem",
#                 "position":"2",
#                 "item":{
#                     "@id":"https://www.eltiempo.com/deportes",
#                     "name":"Deportes"
#                 }
#             },                    {
#                 "@type":"ListItem",
#                 "position":"3",
#                 "item":{
#                     "@id":"https://www.eltiempo.com/deportes/ciclismo",
#                     "name":"Ciclismo"
#                 }
#             }                         ,{
#                 "@type":"ListItem",
#                 "position":"4",
#                 "item":{
#                     "@id":"https://www.eltiempo.com/deportes/ciclismo/mario-sabato-habla-de-nairo-quintana-egan-bernal-y-rigoberto-uran-en-colombia-848931.html",
#                     "name":"Mario Sabato se confiesa en Colombia: &#039;El triunfo de Nairo Quintana me cambió la vida&#039;"
#                 }
#             }
#                 ]
#     ]
# }
#     </script>
# <script defer="" src="https://www.eltiempo.com/assets/article.3f41d7c5716081dee4e8.bundle.js?1717712399" type="text/javascript"></script>
# <script type="text/javascript">
#     window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#         if (!document.getElementById(i)){
#             e.async = 1;
#             e.src = u;
#             e.id = i;
#             f.parentNode.insertBefore(e, f);
#         }
#     }(document.createElement('script'),
#         document.getElementsByTagName('script')[0],
#         '//cdn.taboola.com/libtrc/eltiempoeditorial/loader.js',
#         'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
# </script>
# <link href="https://www.eltiempo.com/favicon.ico?1717712399" rel="shortcut icon">
# </link></link></link></link></meta></meta></meta></meta></meta></head>
# <body class="article-page" page-type="default">
# <script>
# window.disabledAds = [
#     '/login',
#     '/suscripcion-digital',
#     '/zona-usuario/crear',
#     '/zona-usuario/configurar-mis-datos',
#     '/zona-usuario/mi-suscripcion',
#     '/zona-usuario/version-impresa',
#     '/zona-usuario/articulos-guardados',
#     '/zona-usuario/boletines',
#     '/preguntas-frecuentes',
#     '/ayuda',
#     '/politica-privacidad',
#     '/politica-de-cookies',
#     '/mapa-sitio',
#     '/suscripcion-plan-digital-pro',
#     '/happy-hours',
#     '/oferta-especial',
#     '/premium',
#     '/lecturas-dominicales',
#     '/salud/servicio-de-urgencias-en-colombia-la-critica-situacion-del-pais-en-el-sector-de-la-salud-460436',
# ]
# </script>
# <script> document.cookie = "__adblocker=; expires=Thu, 01 Jan 1970 00:00:00 GMT; path=/"; var setNptTechAdblockerCookie = function(adblocker) { var d = new Date(); d.setTime(d.getTime() + 60 * 5 * 1000); document.cookie = "__adblocker=" + (adblocker ? "true" : "false") + "; expires=" + d.toUTCString() + "; path=/"; }; var script = document.createElement("script"); script.setAttribute("async", true); script.setAttribute("src", "//www.npttech.com/advertising.js"); script.setAttribute("onerror", "setNptTechAdblockerCookie(true);"); document.getElementsByTagName("head")[0].appendChild(script); </script>
# <script async="" src="https://buy.tinypass.com/xbuilder/experience/load?aid=3ST2fSyHpu"></script>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WG4KTGL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WG4KTGL" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div class="c-popup c-popup--politicas">
# <div class="c-popup__box">
# <p class="c-popup__text">
#                     En este portal utilizamos datos de navegación / cookies propias y de terceros para gestionar el portal, elaborar información estadística, optimizar la funcionalidad del sitio y mostrar publicidad relacionada con sus preferencias a través del análisis de la navegación. Si continúa navegando, usted estará aceptando esta utilización. Puede conocer cómo deshabilitarlas u obtener más información
#                     <a href="/politica-de-cookies" target="_blank">aquí</a>
# </p>
# <button class="c-popup__button">Entiendo</button>
# </div>
# </div>
# <aside><div class="c-add--no-text c-add-1200x250-desktop" content-ad-type="generated-ad" data-desktop-title="Billboard" data-mobile-title="" style=""></div></aside>
# <nav class="c-topics"><p class="c-topics__title">Temas del día</p><div class="c-topics__wrap" data-btn-next=".c-topics__wrap__btn--next" data-btn-prev=".c-topics__wrap__btn--prev" data-container=".c-topics__wrap__list" data-items="c-topics__wrap__list__item" data-type="topics"><button class="c-topics__wrap__btn c-topics__wrap__btn--prev" type="button"><span class="sr-only">Anterior</span></button><ul class="c-topics__wrap__list"><li class="c-topics__wrap__list__item"><a href="/bogota/en-vivo-movilidad-bogota-asi-amanece-la-movilidad-en-la-capital-este-viernes-7-de-junio-3350343" title="">EN VIVO: Movilidad en Bogotá</a></li><li class="c-topics__wrap__list__item"><a href="/colombia/medellin/emergencia-en-exclusivo-edificio-de-el-poblado-en-medellin-un-ascensor-se-desplomo-en-un-piso-21-y-habria-dos-personas-heridas-3350468" title="">Emergencia en exclusivo edificio en Medellín</a></li><li class="c-topics__wrap__list__item"><a href="/bogota/vacaciones-escolares-de-mitad-de-ano-en-bogota-estas-son-las-fechas-de-receso-de-colegios-privados-y-distritales-para-2024-3350614" title="">Vacaciones escolares de mitad de año en Bogotá</a></li><li class="c-topics__wrap__list__item"><a href="/salud/existe-vacuna-para-la-gripe-aviar-h5n2-3350132" title="">¿Existe vacuna para la gripe aviar H5N2?</a></li><li class="c-topics__wrap__list__item"><a href="/deportes/futbol-colombiano/millonarios-suena-con-la-llegada-de-falcao-y-los-memes-ya-predicen-como-sera-su-etapa-en-bogota-3350610" title="">Millonarios sueña con la llegada de Falcao</a></li><li class="c-topics__wrap__list__item"><a href="/vida/ciencia/el-megacohete-starship-de-spacex-completo-su-primer-vuelo-de-prueba-completo-por-que-es-importante-en-la-carrera-espacial-3350638" title="">Starship de SpaceX completó su primer vuelo </a></li><li class="c-topics__wrap__list__item"><a href="/cultura/musica-y-libros/sorry-4-that-much-la-nueva-cancion-de-feid-3350627" title="">nueva canción de Feid</a></li><li class="c-topics__wrap__list__item"><a href="/cultura/gente/asi-es-el-ritual-a-base-de-romero-para-atraer-la-abundancia-y-la-fortuna-a-su-vida-3350592" title="">ritual a base de romero para atraer la abundancia</a></li></ul><button class="c-topics__wrap__btn c-topics__wrap__btn--next" type="button"><span class="sr-only">Siguiente</span></button></div></nav>
# <header class="c-header" data-scroll-visible-class="c-header--white" data-scroll-visible-ele=".c-subheader" data-type="scroll-visible">
# <div class="c-header__search">
# <button aria-expanded="false" aria-label="Buscador" aria-owns="search-header" class="c-header__search__btn" data-type="search">
# <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M0 0h24v24H0z" fill="none"></path>
# <path d="M15.5 14h-.79l-.28-.27a6.51 6.51 0 1 0-.7.7l.27.28v.79l5 4.99L20.49 19zm-6 0A4.5 4.5 0 1 1 14 9.5 4.494 4.494 0 0 1 9.5 14z" fill="currentColor"></path>
# </svg>
# <span class="sr-only">Buscar</span>
# </button>
# <form action="https://www.eltiempo.com/buscar" aria-hidden="true" class="c-header__search__form" id="search-header">
# <button class="c-header__search__form__btn" type="submit">
# <svg height="15.455" viewbox="0 0 15.504 15.455" width="15.504" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(0.25 0.25)">
# <path d="M6.1,12.209A6.1,6.1,0,0,1,1.788,1.788a6.1,6.1,0,1,1,8.633,8.633A6.063,6.063,0,0,1,6.1,12.209Zm-3.593-9.7A5.08,5.08,0,1,0,6.1,1.024,5.046,5.046,0,0,0,2.512,2.513Z" fill="#05365b" stroke="#05365b" stroke-width="0.5"></path>
# <path d="M4.556,4.908a.349.349,0,0,1-.248-.1L.1.6A.35.35,0,0,1,.6.1L4.8,4.31a.35.35,0,0,1-.248.6Z" fill="#05365b" stroke="#05365b" stroke-width="1" transform="translate(9.796 9.797)"></path>
# </g>
# </svg>
# <span class="sr-only">Buscar</span>
# </button>
# <input autocomplete="off" class="c-header__search__form__input" maxlength="95" name="q" placeholder="Buscar en El Tiempo" target="_top" type="text"/>
# </form>
# </div>
# <div [class]="openNav ? 'c-header__nav open' : 'c-header__nav'" class="c-header__nav">
# <button aria-expanded="false" aria-label="Menu" aria-owns="menu-nav" class="c-header__nav__btn" data-type="menu" on="tap:AMP.setState({openNav: !openNav})">
# <span>Secciones</span>
# <svg class="icon-menu" height="13" viewbox="0 0 17 13" width="17" xmlns="http://www.w3.org/2000/svg">
# <g fill="currentColor" transform="translate(0 1)">
# <path d="M0,1H17" fill="none" stroke="currentColor" stroke-width="2" transform="translate(0 -1)"></path>
# <path d="M0,1H17" fill="none" stroke="currentColor" stroke-width="2" transform="translate(0 4.5)"></path>
# <path d="M0,1H17" fill="none" stroke="currentColor" stroke-width="2" transform="translate(0 10)"></path>
# </g>
# </svg>
# <svg class="icon-closemenu" height="1em" viewbox="0 0 352 512" xmlns="http://www.w3.org/2000/svg">
# <path d="M242.72 256l100.07-100.07c12.28-12.28 12.28-32.19 0-44.48l-22.24-22.24c-12.28-12.28-32.19-12.28-44.48 0L176 189.28 75.93 89.21c-12.28-12.28-32.19-12.28-44.48 0L9.21 111.45c-12.28 12.28-12.28 32.19 0 44.48L109.28 256 9.21 356.07c-12.28 12.28-12.28 32.19 0 44.48l22.24 22.24c12.28 12.28 32.2 12.28 44.48 0L176 322.72l100.07 100.07c12.28 12.28 32.2 12.28 44.48 0l22.24-22.24c12.28-12.28 12.28-32.19 0-44.48L242.72 256z" fill="currentColor"></path>
# </svg>
# </button>
# <nav aria-hidden="true" class="c-header__nav__wrap" id="menu-nav">
# <div class="c-header__nav__darkmode">
# <span class="c-header__nav__darkmode__txt">Activar modo oscuro</span>
# <input class="c-tgl c-tgl-light" id="darkmode" type="checkbox">
# <label class="c-tgl-btn" for="darkmode"></label>
# </input></div>
# <form action="https://www.eltiempo.com/buscar" class="c-header__nav__search" target="_top">
# <input autocomplete="off" maxlength="95" name="q" placeholder="Buscar en El Tiempo" type="text"/>
# </form>
# <div class="c-header__nav__item c-header__nav__item__secciones">
# <div class="c-header__nav__item__cont">
# <span class="c-header__nav__item__link">Secciones</span>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# <path d="M.575,0,5.543,4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(6.755 4.996) rotate(180)"></path>
# </g>
# </svg>
# <span class="sr-only">Abrir</span>
# </button>
# </div>
# <div itemscope="" itemtype="https://www.schema.org/SiteNavigationElement">
# <ul class="c-header__nav__item__sections" role="menu">
# <li class="c-header__nav__item__sections__item">
# <a href="/ultimas-noticias" itemprop="url">Últimas Noticias</a>
# </li>
# <li aria-haspopup="true" class="c-header__nav__item__sections__item" role="menuitem">
# <div class="c-header__nav__item__cont__subsections"> <a href="/economia" itemprop="url">Economia</a>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# <path d="M.575,0,5.543,4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(6.755 4.996) rotate(180)"></path>
# </g>
# </svg>
# <span class="sr-only">Abrir</span>
# </button></div> <ul class="c-header__nav__item__subsections">
# <li>
# <a href="/economia/finanzas-personales" itemprop="url">Finanzas Personales</a>
# </li>
# <li>
# <a href="/economia/empresas" itemprop="url">Empresas</a>
# </li>
# <li>
# <a href="/economia/sectores" itemprop="url">Sectores</a>
# </li>
# <li>
# <a href="/economia/sector-financiero" itemprop="url">Sector Financiero</a>
# </li>
# </ul>
# </li>
# <li aria-haspopup="true" class="c-header__nav__item__sections__item" role="menuitem">
# <div class="c-header__nav__item__cont__subsections"> <a href="/politica" itemprop="url">Politica</a>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# <path d="M.575,0,5.543,4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(6.755 4.996) rotate(180)"></path>
# </g>
# </svg>
# <span class="sr-only">Abrir</span>
# </button></div> <ul class="c-header__nav__item__subsections">
# <li>
# <a href="/politica/gobierno" itemprop="url">Gobierno</a>
# </li>
# <li>
# <a href="/politica/congreso" itemprop="url">Congreso</a>
# </li>
# <li>
# <a href="/politica/proceso-de-paz" itemprop="url">Proceso de Paz</a>
# </li>
# <li>
# <a href="/politica/partidos-politicos" itemprop="url">Partidos Políticos</a>
# </li>
# </ul>
# </li>
# <li aria-haspopup="true" class="c-header__nav__item__sections__item" role="menuitem">
# <div class="c-header__nav__item__cont__subsections"> <a href="/colombia" itemprop="url">Colombia</a>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# <path d="M.575,0,5.543,4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(6.755 4.996) rotate(180)"></path>
# </g>
# </svg>
# <span class="sr-only">Abrir</span>
# </button></div> <ul class="c-header__nav__item__subsections">
# <li>
# <a href="/bogota" itemprop="url">Bogotá</a>
# </li>
# <li>
# <a href="/colombia/medellin" itemprop="url">Medellín</a>
# </li>
# <li>
# <a href="/colombia/barranquilla" itemprop="url">Barranquilla</a>
# </li>
# <li>
# <a href="/colombia/cali" itemprop="url">Cali</a>
# </li>
# <li>
# <a href="/colombia/santander" itemprop="url">Santander</a>
# </li>
# </ul>
# </li>
# <li class="c-header__nav__item__sections__item">
# <a href="/bogota" itemprop="url">Bogotá</a>
# </li>
# <li aria-haspopup="true" class="c-header__nav__item__sections__item" role="menuitem">
# <div class="c-header__nav__item__cont__subsections"> <a href="/opinion" itemprop="url">Opinión</a>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# <path d="M.575,0,5.543,4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(6.755 4.996) rotate(180)"></path>
# </g>
# </svg>
# <span class="sr-only">Abrir</span>
# </button></div> <ul class="c-header__nav__item__subsections">
# <li>
# <a href="https://www.eltiempo.com/opinion" itemprop="url">Columnistas</a>
# </li>
# <li>
# <a href="/opinion/editorial" itemprop="url">Editorial</a>
# </li>
# <li>
# <a href="/opinion/caricaturas" itemprop="url">Caricaturas</a>
# </li>
# <li>
# <a href="https://blogs.eltiempo.com" itemprop="url">Blogs</a>
# </li>
# </ul>
# </li>
# <li class="c-header__nav__item__sections__item">
# <a href="/unidad-investigativa" itemprop="url">Unidad Investigativa</a>
# </li>
# <li class="c-header__nav__item__sections__item">
# <a href="/especiales" itemprop="url">Especiales</a>
# </li>
# <li class="c-header__nav__item__sections__item">
# <a href="/salud" itemprop="url">Salud</a>
# </li>
# <li aria-haspopup="true" class="c-header__nav__item__sections__item" role="menuitem">
# <div class="c-header__nav__item__cont__subsections"> <a href="/mundo" itemprop="url">Internacional</a>
# <button class="c-header__nav__item__btn" data-type="toggleMenu" type="button">
# <svg height="7.092" viewbox="0 0 12.011 7.092" width="12.011" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(11.155 -0.152) rotate(90)">
# <path d="M.575,0,5.543-4.791" fill="none" stroke="currentColor" stroke-linecap="square" stroke-width="1.5" transform="translate(0.64 10.095)"></path>
# ...
# <div class="c-lomas__article__txt">
# <p class="c-lomas__article__epigraph">
# <a href="https://www.eltiempo.com/bogota" title="Bogotá">Bogotá</a>
# <time class="c-article__date" datetime="1717800447">                        05:47 P.M.
#
# </time>
# </p>
# <h4 class="c-lomas__article__title" itemprop="headline">
# <a href="/bogota/mujer-termino-secuestrada-y-robada-despues-de-encontrarse-con-un-hombre-que-conocio-en-app-de-citas-3350657">
#             Mujer terminó golpeada y sin pertenencias después de citarse con un hombre que conoció en internet: 'Me tuve que tirar por la ventana'
#         </a>
# </h4>
# </div>
# </article><article class="c-lomas__article c-lomas__article c-lomas__article--default" data-autor="Harold yepes izquierdo" data-bloqueo="Abierto" data-board="Lo mas visto" data-category="Deportes/futbol internacional" data-clasecontenido="Tendencia" data-editorial="Editorial" data-id="3350681" data-name="Chile estaria atravesando una crisis antes de la copa america: el sueldo de ricardo gareca, embolatado" data-position="3" data-publicacion="2024-06-07" data-redactorvisible="Redaccion el tiempo" data-seccion="Deportes" data-subseccion="Futbol internacional" data-tipocontenido="Articulo">
# <div class="c-lomas__article__txt">
# <p class="c-lomas__article__epigraph">
# <a href="https://www.eltiempo.com/deportes/futbol-internacional" title="Fútbol Internacional">Fútbol Internacional</a>
# <time class="c-article__date" datetime="1717800261">                        05:44 P.M.
#
# </time>
# </p>
# <h4 class="c-lomas__article__title" itemprop="headline">
# <a href="/deportes/futbol-internacional/chile-estaria-atravesando-una-crisis-antes-de-la-copa-america-el-sueldo-de-ricardo-gareca-embolatado-3350681">
#             Chile estaría atravesando una crisis antes de la Copa América: el sueldo de Ricardo Gareca, embolatado
#         </a>
# </h4>
# </div>
# </article><article class="c-lomas__article c-lomas__article c-lomas__article--default" data-autor="Wendys loraine pitre ariza" data-bloqueo="Abierto" data-board="Lo mas visto" data-category="Cultura/gente" data-clasecontenido="Tendencia" data-editorial="Editorial" data-id="3350678" data-name="Estos son los importantes negocios de 'ceta' y ‘valkiria’ ganadores del 'desafio 2022'" data-position="4" data-publicacion="2024-06-07" data-redactorvisible="Redaccion el tiempo" data-seccion="Cultura" data-subseccion="Gente" data-tipocontenido="Articulo">
# <div class="c-lomas__article__txt">
# <p class="c-lomas__article__epigraph">
# <a href="https://www.eltiempo.com/cultura/gente" title="Gente">Gente</a>
# <time class="c-article__date" datetime="1717800229">                        05:48 P.M.
#
# </time>
# </p>
# <h4 class="c-lomas__article__title" itemprop="headline">
# <a href="/cultura/gente/estos-son-los-importantes-negocios-de-ceta-y-valkiria-ganadores-de-desafio-2022-3350678">
#             Estos son los importantes negocios de 'Ceta' y ‘Valkiria’ ganadores del 'Desafío 2022'
#         </a>
# </h4>
# </div>
# </article><article class="c-lomas__article c-lomas__article c-lomas__article--default" data-autor="User admin" data-bloqueo="Abierto" data-board="Lo mas visto" data-category="Mundo/latinoamerica" data-clasecontenido="Estandar" data-editorial="Editorial" data-id="3350669" data-name="Al menos un estudiante muerto y otro herido tras un tiroteo en un campus universitario en panama" data-position="5" data-publicacion="2024-06-07" data-redactorvisible="Redaccion el tiempo" data-seccion="Mundo" data-subseccion="Latinoamerica" data-tipocontenido="Articulo">
# <div class="c-lomas__article__txt">
# <p class="c-lomas__article__epigraph">
# <a href="https://www.eltiempo.com/mundo/latinoamerica" title="Latinoamérica">Latinoamérica</a>
# <time class="c-article__date" datetime="1717799444">                        05:30 P.M.
#
# </time>
# </p>
# <h4 class="c-lomas__article__title" itemprop="headline">
# <a href="/mundo/latinoamerica/al-menos-un-estudiante-muerto-en-un-tiroteo-en-un-campus-universitario-en-panama-3350669">
#             Al menos un estudiante muerto y otro herido tras un tiroteo en un campus universitario en Panamá
#         </a>
# </h4>
# </div>
# </article></div></div></div></div><aside class="c-detail-sidebar__aside"><div class="ads"><div class="u-hide-sm u-show-md"><aside><div class="c-add c-add-300x600-desktop" content-ad-type="generated-ad" data-desktop-title="Banner 300x600" data-mobile-title="" style=""></div></aside></div></div></aside><div class="c-boletin"><a href="/zona-usuario/boletines" title="Boletines"><img alt="" height="381" loading="lazy" src="/images/boletines.png" width="300"/></a></div>
# <div class="viafoura u-sticky u-sticky--viafoura" data-type="viafoura-starter">
# <vf-conversation-starter description="Cuéntanos tu opinión sobre este artículo" minimum-comment-count="1" target="3285629" title="Todos tenemos algo por decir" vf-container-id="3285629">
# </vf-conversation-starter>
# </div>
# </div>
# </div>
# </div></article>
# </div>
# </section>
# <div class="modal" id="articleModal"></div>
# <section class="paywall" id="paywall">
# <div class="signwall-notificacion" id="signwall-notificacion"></div>
# <div class="signwall-notificacion-webview" id="signwall-notificacion"></div>
# </section>
# <img class="img-tracking" height="1" src="https://www.eltiempo.com/track/pageviews/article-3285629" width="1">
# <section class="o-section">
# <div class="o-container" style="background-color: #f2f2f2">
# <div id="taboola-below-article-thumbnails"></div>
# <script type="text/javascript">
#     window._taboola = window._taboola || [];
#     if (window.innerWidth <= 768) {
#         if (document.getElementById("taboola-below-article-thumbnails")){
#             const div = document.getElementById("taboola-below-article-thumbnails");
#             div.setAttribute("id", "taboola-mobile-below-article-thumbnails");
#         }
#         _taboola.push({
#             mode: 'thumbnails-a-1x1-mobile',
#             container: 'taboola-mobile-below-article-thumbnails',
#             placement: 'Mobile Below Article Thumbnails',
#             target_type: 'mix'
#         });
#     } else {
#         if (document.getElementById("taboola-mobile-below-article-thumbnails")){
#             const div = document.getElementById("taboola-mobile-below-article-thumbnails");
#             div.setAttribute("id", "taboola-below-article-thumbnails");
#         }
#         _taboola.push({
#             mode: 'thumbnails-a-5x1-desk',
#             container: 'taboola-below-article-thumbnails',
#             placement: 'Below Article Thumbnails',
#             target_type: 'mix'
#         });
#     }
# </script>
# </div>
# </section>
# <script src="https://unpkg.com/@lottiefiles/lottie-player@latest/dist/lottie-player.js"></script>
# <footer class="c-footer">
# <div class="c-footer__top">
# <div class="o-container">
# <div class="c-footer__group c-footer__group--a">
# <div class="c-footer__brand"><a href="https://www.eltiempo.com/" rel="nofollow noreferrer" title="eltiempo.com"></a><img alt="logo_eltiempo_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_eltiempo_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_eltiempo_footer.svg" width="112"/></div>
# <nav class="c-footer__social"><p class="c-footer__social__title">Síguenos en:</p><ul class="c-footer__social__list"><li class="c-footer__social__item"><a href="https://api.whatsapp.com/send/?phone=573223090079&amp;text&amp;app_absent=0" rel="nofollow noreferrer" target="_blank"></a><img alt="logo_wap_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_wap_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_wap_footer.svg" width="20"/></li><li class="c-footer__social__item"><a href="https://www.facebook.com/eltiempo" rel="nofollow noreferrer" target="_blank"></a><img alt="logo_fb_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_fb_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_fb_footer.svg" width="20"/></li><li class="c-footer__social__item"><a href="https://twitter.com/eltiempo" rel="nofollow noreferrer" target="_blank"></a><img alt="logo_tw_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_tw_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_tw_footer.svg" width="20"/></li><li class="c-footer__social__item"><a href="https://www.youtube.com/user/ElTiempoPLAY" rel="nofollow noreferrer" target="_blank"></a><img alt="logo_yt_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_yt_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_yt_footer.svg" width="20"/></li><li class="c-footer__social__item"><a href="https://www.instagram.com/eltiempo/" rel="nofollow noreferrer" target="_blank"></a><img alt="logo_ig_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_ig_footer.svg" height="20" loading="lazy" src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_ig_footer.svg" width="20"/></li></ul></nav>
# </div>
# <div class="c-footer__group c-footer__group--b">
# <ul aria_label="Footer Menu" class="c-footer__nav" role="footer-menu-item">
# <li>
# <a href="/ayuda" itemprop="url">Ayuda</a>
# </li>
# <li>
# <a href="/politica-privacidad" itemprop="url">Aviso de Privacidad</a>
# </li>
# <li>
# <a href="/terminos-condiciones" itemprop="url">Términos y Condiciones</a>
# </li>
# <li>
# <a href="/politica-de-cookies" itemprop="url">Política de Cookies</a>
# </li>
# <li>
# <a href="/mapa-sitio" itemprop="url">Mapa del Sitio</a>
# </li>
# <li aria-haspopup="true" class="c-footer__nav__item" role="footer-menu-subitem">
# <div class="c-footer__nav__item__cont">
# <span class="c-footer__nav__item__title" data-parent-second-level="" data-type="toggleFooter">Conoce Nuestros Portales</span>
# </div> <ul class="c-footer__nav__item__subsections">
# <li>
# <a href="https://www.portafolio.co/" itemprop="url" target="_blank">Noticias de Economia - Portafolio</a>
# </li>
# <li>
# <a href="http://elempleo.com/" itemprop="url" target="_blank">Empleos en Colombia - El Empleo</a>
# </li>
# <li>
# <a href="http://futbolred.com/" itemprop="url" target="_blank">Noticias de Fútbol - Fútbolred</a>
# </li>
# <li>
# <a href="https://www.motor.com.co/" itemprop="url" target="_blank">Novedades del Sector Automotriz - Motor</a>
# </li>
# <li>
# <a href="https://citytv.eltiempo.com/" itemprop="url" target="_blank">Noticias de Bogotá - CityTV</a>
# </li>
# <li>
# <a href="http://diarioadn.co/" itemprop="url" target="_blank">Noticias de Actualidad - Diario ADN</a>
# </li>
# <li>
# <a href="https://www.alo.co/" itemprop="url" target="_blank">Espacio Dedicado a Mujeres - Aló</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/servicio-al-cliente" itemprop="url">Servicio al Cliente</a>
# </li>
# <li>
# <a href="https://www.eltiempocasaeditorial.com/linea-etica" itemprop="url" target="_blank">Línea Ética</a>
# </li>
# <li>
# <a href="https://www.clubvivamos.com/" itemprop="url" target="_blank">Club EL Tiempo Vivamos</a>
# </li>
# <li>
# <a href="/rss" itemprop="url">RSS</a>
# </li>
# <li>
# <a href="https://cursos.eltiempo.com/" itemprop="url" target="_blank">Cursos El Tiempo</a>
# </li>
# <li>
# <a href="https://www.eltiempocasaeditorial.com/" itemprop="url" target="_blank">Casa Editorial El Tiempo</a>
# </li>
# <li>
# <a href="https://tienda.eltiempo.com/" itemprop="url" target="_blank">Colecciones El Tiempo</a>
# </li>
# <li>
# <a href="http://www.audienciadigital.co/" itemprop="url" target="_blank">Paute con nosotros</a>
# </li>
# <li>
# <a href="https://www.elempleo.com/sitios-empresariales/colombia/el-tiempo-casa-editorial/" itemprop="url" target="_blank">Trabaje con nosotros</a>
# </li>
# <li>
# <a href="/publicidad-politica-pagada" itemprop="url">Publicidad Política Pagada</a>
# </li>
# <li>
# <a href="https://seg.eltiempo.com/suscripciones/impreso/eltiempodigital" itemprop="url" target="_blank">Suscribirse</a>
# </li>
# <li>
# <a href="https://www.eltiempocasaeditorial.com/solicitud-reversion-de-pago" itemprop="url" target="_blank">Reversión de Pago</a>
# </li>
# </ul>
# <div class="c-footer__members"><p class="c-footer__members__title">MIEMBRO DE</p><div class="c-footer__members__claim"><figure class="c-footer__members__claim__thumb"><img alt="logo_gda_footer" data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/05/65e72f7151d64.png" height="23" loading="lazy" src="https://imagenes.eltiempo.com/files/image_41_23/uploads/2024/03/05/65e72f7151d64.png" width="41"/></figure><div class="c-footer__members__claim__txt"><p class="c-footer__members__claim__title">Grupo de Diarios de América</p></div><a></a></div><div class="c-footer__members__claim"><figure class="c-footer__members__claim__thumb"><img alt="Logo Ami" data-full-src="https://imagenes.eltiempo.com/uploads/2017/09/29/59ce9d47cc9a2.png" height="23" loading="lazy" src="https://imagenes.eltiempo.com/files/image_41_23/uploads/2017/09/29/59ce9d47cc9a2.png" width="41"/></figure><div class="c-footer__members__claim__txt"><p class="c-footer__members__claim__title">Asociación Colombiana de Medios de Información</p></div><a href="https://ami.org.co/" rel="nofollow noreferrer" target="_blank"></a></div><div class="c-footer__members__claim"><figure class="c-footer__members__claim__thumb"><img alt="logo_iab_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_iab_footer.png" height="23" loading="lazy" src="https://imagenes.eltiempo.com/files/image_41_23/uploads/2024/03/02/logo_iab_footer.png" width="41"/></figure><div class="c-footer__members__claim__txt"><p class="c-footer__members__claim__title">Interactive Advertisement Bureau</p></div><a href="https://www.iab.com/" rel="nofollow noreferrer" target="_blank"></a></div><div class="c-footer__members__claim"><figure class="c-footer__members__claim__thumb"><img alt="logo_super_footer." data-full-src="https://imagenes.eltiempo.com/uploads/2024/03/02/logo_super_footer.png" height="23" loading="lazy" src="https://imagenes.eltiempo.com/files/image_41_23/uploads/2024/03/02/logo_super_footer.png" width="41"/></figure><div class="c-footer__members__claim__txt"><p class="c-footer__members__claim__title">Superintendencia de Industria y Comercio</p></div><a href="https://www.sic.gov.co/" rel="nofollow noreferrer" target="_blank"></a></div></div>
# </div>
# </div>
# </div>
# <div class="c-footer__bottom">
# <div class="o-container">
# <p class="c-footer__copy">COPYRIGHT © 2024 EL TIEMPO Casa Editorial NIT. 860.001.022-7. Prohibida su reproducción total o parcial, o su uso para el desarrollo de programas de inteligencia artificial o aprendizaje automático, así<br/>como su traducción a cualquier idioma, sin autorización escrita de su titular. ELTIEMPO.com todas las noticias de Colombia y el Mundo.</p><p class="c-footer__copy">.</p>
# </div>
# </div>
# </footer>
# <script async="" src="//cdn.viafoura.net/entry/index.js" type="text/javascript"></script>
# <style>
# </style>
# <script type="text/javascript">
#     window._taboola = window._taboola || [];
#     _taboola.push({article:'auto'});
#     !function (e, f, u, i) {
#         if (!document.getElementById(i)){
#             e.async = 1;
#             e.src = u;
#             e.id = i;
#             f.parentNode.insertBefore(e, f);
#         }
#     }(document.createElement('script'),
#         document.getElementsByTagName('script')[0],
#         '//cdn.taboola.com/libtrc/eltiempoeditorial/loader.js',
#         'tb_loader_script');
#     if(window.performance && typeof window.performance.mark == 'function')
#     {window.performance.mark('tbl_ic');}
# </script>
# </img></body>
# </html>

# %% [markdown]
# | Titulo | Fecha | Contenido |
# |--------|-------|-----------|
# | Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida' | [Fecha de la noticia] | [Contenido de la noticia] |

# %%
# Ingrese su código acá
title_tag = soup.find('h1').get_text() ;print(title_tag)
# Out:
# Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida'

# %%
author_tag = soup.find('a', class_='c-detail__author__name').get_text() ;print(author_tag)
# Out:
# Andrés Felipe Balaguera Sarmiento

# %%
date_tag = soup.find('time').get_text()
date_tag
# Out:
# 'enero 27 de 2024, 12:00 A.M.'

# %%
content_tags = soup.find_all('div', class_='paragraph')
content = ' '.join([p.get_text() for p in content_tags])
content
# Out:
# "Nairo Quintana, de 1,68 metros de estatura, se agigantó entre el 9 de mayo y el 1 de junio del 2014. El ciclista boyacense, por entonces una revelación mundial tras el subcampeonato en el Tour de Francia de 2013, le dio a Colombia su segundo título en una de las tres grandes, luego de la Vuelta a España que ganó ‘Lucho’ Herrera en 1987. El país, lleno de emoción, vibró con el triunfo de ‘Nairoman’ en el Giro de Italia. Y lo hizo gracias al apasionado relato del hombre que ha narrado durante los últimos años las grandes hazañas del ciclismo colombiano: Mario Sabato. Argentino de nacimiento, pero colombiano por convicción, Sabato ha sido quien les ha dado voz a los triunfos de Egan y Nairo, los embalajes de Gaviria y Molano, los triunfos de Mariana Pajón, las escaladas de Sergio Higuita, las luchas de Rigoberto Urán y los golpes sobre la mesa de Santiago Buitrago, Einer Rubio y tantos más. Su relato, una marca registrada durante 15 años en la cadena internacional ESPN, migra ahora a RCN, el canal con el que ayer debutó en los nacionales de ciclismo y en el que espera seguir narrando las batallas de los ‘escarabajos’. La verdad que es un desafío muy importante, es un desafío muy grande para mi carrera venir a Colombia. Yo estuve 15 años en Espn y, como puse el otro día cuando me despedía, fui muy feliz, crecí muchísimo como persona y como profesional, pero, bueno, cuando me propusieron este reto era como una combinación de todo lo que yo quería hacer porque yo amo narrar las carreras internacionales, las mejores carreras del mundo, pero también tenía una deuda pendiente porque yo digo: ‘Vengo siempre a Colombia 10, 12 veces al año y nunca pude narrar una carrera colombiana’. Sí, cuando Andrea Guerrero (gerente de Deportes en RCN) me dice: ‘Mira, Mario, vamos a tener Giro, Tour, Vuelta, Olímpicos, bla bla bla bla, todas las carreras del calendario internacional’, dije: ‘Buenísimo, okay, lo mismo que yo hago’, y me dice: ‘Noo, pero también vamos a tener Vuelta a Colombia, Clásico RCN…’, ahí yo digo: ‘Ufff, qué interesante’, porque como que yo adentro mío tenía esa deuda pendiente y, bueno, se combinó todo de una manera perfecta y acá estoy como el nuevo narrador de ciclismo de RCN, que para mí es un placer muy grande. Bueno, yo tengo mi familia, mi tío Carlos Reybaud, que fue ciclista, que corrió los Juegos Olímpicos, que fue campeón argentino varias veces y a raíz de seguirlo a él, si bien nosotros en Argentina nacemos con una pelota de fútbol en la cabeza porque es así, ¿eh? (risas), los sábados eran de ir a la cancha a ver a mi querido Sportivo Italiano, de la Cuarta División de Argentina, y los domingos de ir a ver a mi tío correr en el circuito de Loma, de Bellavista… entonces empecé a forjar esa pasión por el ciclismo. Yo siempre digo que es imposible no enamorarse del ciclismo. Y, bueno, desarrollé la pasión viniendo de un país donde el ciclismo la verdad que es muy poco, por no decir casi nada, difundido lamentablemente. Duré un día nada más porque es demasiado difícil el ciclismo. Yo lo intenté, me subí por única vez en serio a tratar de ser ciclista en la pista que lleva el nombre de mi abuelo, Diego Reybaud, pero la bicicleta de pista, no sé si la gente sabe, pero no tiene frenos, son de piñón fijo, y fue tan difícil…. cuando me quedé en medio de un pelotón, con tantos ciclistas alrededor, dije ‘No…’. Logré bajarme de la bicicleta y sentí que era imposible. Yo, desde ese momento, con 12 o 13 años, dije: es muy difícil ser ciclista. O sea, a partir de ahí, mi admiración creció a niveles como los que tengo hoy por los ciclistas… que están en el deporte más lindo del mundo, pero a la vez en el más difícil. Porque es imposible lo que hacen los ciclistas, porque correr día a día cinco o seis horas y al día siguiente volver a correr otras cinco o seis horas, y al día siguiente otras cinco o seis horas…, mantener promedios por encima de 40 km por hora. Yo a la gente le digo: ‘Agarren la bicicleta de quien quieran: la de Nairo, ...

# %% [markdown]
# cree un dataframe con la siguiente extructura y cargeue 3 noticias de la página de eltiempo.com
#
#  | Titulo | Fecha | Contenido |Autor|url|
# |--------|-------|-----------|------|---|
# | Mario Sabato se confiesa en Colombia: 'El triunfo de Nairo Quintana me cambió la vida' | [Fecha de la noticia] | [Contenido de la noticia] |[Autor]|[url]|

# %%
import pandas as pd
from datetime import datetime
import pytz
import json

feed_response = requests.get(url)

data_rows=[]

if feed_response.status_code == 200:

    title_tag = soup.find('h1').get_text()
    author_tag = soup.find('a', class_='c-detail__author__name').get_text()
    date_tag = soup.find('time').get_text()
    content_tags = soup.find_all('div', class_='paragraph')
    content = ' '.join([p.get_text() for p in content_tags])

    # Prepara la fila de datos
    data_rows.append((title_tag,  date_tag,author_tag, content,url))
column_names = ["Titulo", "Fecha", "Contenido","Autor", "Url"]
df=pd.DataFrame(data_rows,columns=column_names)
df
# Out:
#                                               Titulo  \
# 0  Mario Sabato se confiesa en Colombia: 'El triu...
#
#                           Fecha                          Contenido  \
# 0  enero 27 de 2024, 12:00 A.M.  Andrés Felipe Balaguera Sarmiento
#
#                                                Autor  \
# 0  Nairo Quintana, de 1,68 metros de estatura, se...
#
#                                                  Url
# 0  https://www.eltiempo.com/deportes/ciclismo/mar...

# %% [markdown]
# **Ejercicio 2** (7 min)
#
# Extraiga la información de las primeras 3 noticias del sitemap

# %%
# @title
urls=['https://www.eltiempo.com/cultura/gente/asi-luce-hoy-juan-carlos-villegas-presentador-de-tambien-caeras-y-no-me-lo-cambie-3350607',
     'https://www.eltiempo.com/mundo/eeuu-y-canada/como-se-si-me-esta-dando-un-golpe-de-calor-las-senales-ante-la-ola-extrema-en-ee-uu-3350605',
     'https://www.eltiempo.com/bogota/en-vivo-movilidad-bogota-asi-amanece-la-movilidad-en-la-capital-este-viernes-7-de-junio-3350343']
for enlace in urls:
  # Realizar la solicitud HTTP para obtener el contenido de la página
  respuesta = requests.get(enlace)

  # Parsear el contenido HTML con BeautifulSoup
  soup = BeautifulSoup(respuesta.content, 'html.parser')
  # Realizar una petición GET a la URL del feed
  feed_response = requests.get(enlace)
  # Verificar si la respuesta es exitosa
  if feed_response.status_code == 200:
    title_tag = soup.find('h1').get_text()
    author_tag = soup.find('a', class_='c-detail__author__name').get_text()
    date_tag = soup.find('time').get_text()
    content_tags = soup.find_all('div', class_='paragraph')
    content = ' '.join([p.get_text() for p in content_tags])

    # Prepara la fila de datos
    data_rows.append((title_tag,  date_tag,author_tag, content,url))
column_names = ["Titulo", "Fecha", "Contenido","Autor", "Url"]
df=pd.DataFrame(data_rows,columns=column_names)
df
# Out:
#                                               Titulo  \
# 0  Mario Sabato se confiesa en Colombia: 'El triu...
# 1  Así luce hoy Juan Carlos Villegas, presentador...
# 2  ¿Cómo sé si me está dando un golpe de calor? L...
# 3  EN VIVO | Movilidad en Bogotá: se reportan man...
#
#                           Fecha                          Contenido  \
# 0  enero 27 de 2024, 12:00 A.M.  Andrés Felipe Balaguera Sarmiento
# 1   junio 7 de 2024, 03:25 P.M.      Karen Dahiana Lopez Castañeda
# 2   junio 7 de 2024, 03:25 P.M.                       Pedro Ioskyn
# 3   junio 7 de 2024, 05:48 P.M.         redacción últimas noticias
#
#                                                Autor  \
# 0  Nairo Quintana, de 1,68 metros de estatura, se...
# 1  (Le podría interesar: Esta es la enfermedad qu...
# 2  Ante las elevadas temperaturas que provocaron ...
# 3  Por otra parte, viajeros pueden empezar a sali...
#
#                                                  Url
# 0  https://www.eltiempo.com/deportes/ciclismo/mar...
# 1  https://www.eltiempo.com/deportes/ciclismo/mar...
# 2  https://www.eltiempo.com/deportes/ciclismo/mar...
# 3  https://www.eltiempo.com/deportes/ciclismo/mar...

# %% [markdown]
# Ahora leeremos la información de los ids directamente de https://www.eltiempo.com/sitemap-articles-current.xml

# %%
import re

url = 'https://www.eltiempo.com/sitemap-articles-current.xml'
session = requests.Session()

# Realizar solicitud inicial
response = session.get(url)
soup = BeautifulSoup(response.content, 'lxml')
sitemap_urls = [loc.text for loc in soup.find_all('loc')]

sitemap_urls
# Out:
# <ipython-input-115-f4b58025c731>:8: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   soup = BeautifulSoup(response.content, 'lxml')
# ['https://www.eltiempo.com/colombia/barranquilla/infraestructura-de-primer-nivel-y-clima-favorable-posicionan-a-barranquilla-como-destino-de-turismo-de-reuniones-3350663',
#  'https://www.eltiempo.com/bogota/en-vivo-movilidad-bogota-asi-amanece-la-movilidad-en-la-capital-este-viernes-7-de-junio-3350343',
#  'https://www.eltiempo.com/justicia/conflicto-y-narcotrafico/urgente-escalada-terrorista-contra-la-policia-explota-carro-bomba-en-robles-y-atacan-con-tatucos-el-comando-de-la-institucion-en-popayan-3350675',
#  'https://www.eltiempo.com/cultura/gente/estos-son-los-importantes-negocios-de-ceta-y-valkiria-ganadores-de-desafio-2022-3350678',
#  'https://www.eltiempo.com/bogota/mujer-termino-secuestrada-y-robada-despues-de-encontrarse-con-un-hombre-que-conocio-en-app-de-citas-3350657',
#  'https://www.eltiempo.com/deportes/futbol-internacional/chile-estaria-atravesando-una-crisis-antes-de-la-copa-america-el-sueldo-de-ricardo-gareca-embolatado-3350681',
#  'https://www.eltiempo.com/bogota/region-metropolitana-chia-da-paso-clave-para-convertirse-en-nuevo-socio-de-bogota-soacha-y-cundinamarca-alcalde-explica-decision-3350639',
#  'https://www.eltiempo.com/colombia/cali/lo-ultimo-reportan-una-fuerte-explosion-en-el-corregimiento-de-robles-en-jamundi-3350662',
#  'https://www.eltiempo.com/mundo/latinoamerica/al-menos-un-estudiante-muerto-en-un-tiroteo-en-un-campus-universitario-en-panama-3350669',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/fuad-char-revelo-cuales-serian-los-dos-primeros-refuerzos-de-junior-para-la-siguiente-temporada-3350664',
#  'https://www.eltiempo.com/cultura/musica-y-libros/sorry-4-that-much-la-nueva-cancion-de-feid-3350627',
#  'https://www.eltiempo.com/cultura/gente/quien-es-santiago-talledo-el-exnovio-de-greeicy-rendon-que-se-declaro-gay-y-dijo-que-lo-sabia-desde-que-salio-con-la-calena-3350382',
#  'https://www.eltiempo.com/colombia/otras-ciudades/gustavo-petro-en-suiza-reforma-pensional-la-final-de-la-liga-beplay-3350647',
#  'https://www.eltiempo.com/cultura/gente/farina-regresa-a-la-musica-con-un-nuevo-nombre-artistico-y-ritmo-tropical-en-su-cancion-el-caballito-3350655',
#  'https://www.eltiempo.com/economia/sectores/siete-empresas-firman-acuerdo-para-bajar-las-tarifas-de-energia-entre-un-4-y-20-cuales-son-3350660',
#  'https://www.eltiempo.com/contenido-comercial/crecimiento-y-expansion-con-el-programa-partners-de-q10-3350624',
#  'https://www.eltiempo.com/salud/las-estrategias-de-colombia-para-vigilar-la-gripe-aviar-esta-semana-la-oms-confirmo-la-primera-muerte-en-el-mundo-3350119',
#  'https://www.eltiempo.com/mundo/europa/mette-frederiksen-primera-ministra-de-dinamarca-fue-agredida-por-un-hombre-en-una-plaza-de-copenhague-esto-se-sabe-3350637',
#  'https://www.eltiempo.com/colombia/barranquilla/dia-mundial-del-medioambiente-barranquilla-sigue-celebrando-con-actividades-en-el-gran-malecon-y-la-cienaga-de-mallorquin-3350653',
#  'https://www.eltiempo.com/salud/tiempo-de-correr-se-necesitan-plantillas-personalizadas-para-hacer-running-quienes-deberian-usarlas-y-para-que-sirven-3350644',
#  'https://www.eltiempo.com/cultura/gente/ryan-castro-gana-segunda-demanda-contra-kings-records-3350626',
#  'https://www.eltiempo.com/cultura/gente/tras-demanda-a-caracol-television-el-comediante-alerta-aseguro-que-volveria-a-sabados-felices-con-estas-condiciones-3349761',
#  'https://www.eltiempo.com/cultura/gente/video-campesinos-probaron-comida-gomela-y-estuvieron-a-punto-de-vomitar-eso-es-muy-asqueroso-3350125',
#  'https://www.eltiempo.com/cultura/gente/por-que-la-gripa-esta-dando-tan-duro-en-bogota-cali-medellin-y-otras-ciudades-de-colombia-esto-dice-epidemiologo-3350021',
#  'https://www.eltiempo.com/vida/ciencia/el-megacohete-starship-de-spacex-completo-su-primer-vuelo-de-prueba-completo-por-que-es-importante-en-la-carrera-espacial-3350638',
#  'https://www.eltiempo.com/colombia/medellin/fatal-accidente-en-medellin-una-nina-de-cuatro-anos-murio-tras-caer-de-un-piso-13-3350646',
#  'https://www.eltiempo.com/cultura/gente/video-descubren-que-yuntai-la-supuesta-cascada-mas-alta-de-china-es-en-realidad-un-conjunto-de-tuberias-3350623',
#  'https://www.eltiempo.com/deportes/futbol-internacional/video-durante-un-partido-de-futbol-femenino-jugadora-noquea-a-otra-generando-indignacion-entre-los-aficionados-3350629',
#  'https://www.eltiempo.com/vida/ciencia/un-meteorito-cayo-en-colombia-esto-se-sabe-hasta-ahora-del-evento-que-ilumino-los-cielos-el-30-de-mayo-3349393',
#  'https://www.eltiempo.com/colombia/otras-ciudades/policias-fueron-recibidos-con-machete-y-agua-caliente-en-un-allanamiento-en-belen-risaralda-3350621',
#  'https://www.eltiempo.com/colombia/otras-ciudades/alerta-roja-en-el-municipio-de-macanal-fuerte-invierno-afecta-las-vias-y-trunca-la-movilidad-en-el-territorio-3350603',
#  'https://www.eltiempo.com/bogota/racionamiento-de-agua-en-bogota-estos-son-los-barrios-que-tendran-cortes-este-sabado-8-de-junio-3346688',
#  'https://www.eltiempo.com/justicia/cortes/los-alcances-de-la-decision-de-la-comision-de-disciplina-judicial-contra-el-fiscal-mario-burgos-por-supuesta-filtracion-de-video-de-nicolas-petro-3350642',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/uscis-anuncio-un-cambio-importante-en-los-requisitos-para-ciertos-solicitantes-3350606',
#  'https://www.eltiempo.com/deportes/otros-deportes/increible-amargura-y-cara-de-terror-atleta-pierde-medalla-europea-de-forma-dramatica-por-festejar-antes-de-tiempo-video-3350640',
#  'https://www.eltiempo.com/colombia/otras-ciudades/reportan-sismo-durante-la-tarde-del-viernes-en-colombia-conozca-la-magnitud-y-el-epicentro-3350633',
#  'https://www.eltiempo.com/salud/eps-sanitas-el-nivel-de-satisfaccion-de-los-usuarios-crecio-un-74-en-2023-cuando-todavia-no-estaba-intervenida-3350635',
#  'https://www.eltiempo.com/deportes/futbol-internacional/para-oscar-cordoba-no-es-momento-para-que-james-rodriguez-llegue-a-boca-no-hay-aguas-tibias-3350636',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/donald-trump-puede-viajar-fuera-de-estados-unidos-tras-ser-declarado-culpable-3350618',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/como-se-define-el-titulo-de-la-liga-betplay-entre-santa-fe-y-bucaramanga-que-pasa-si-hay-empate-3350634',
#  'https://www.eltiempo.com/mundo/europa/rusia-no-descarta-cambios-en-su-doctrina-nuclear-ante-las-amenazas-de-occidente-3350604',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/trabajaban-en-una-piscina-de-pelotas-y-encontraron-un-accesorio-de-miles-de-dolares-3350588',
#  'https://www.eltiempo.com/cultura/gente/cuando-se-estrena-intensamente-2-en-que-cines-estara-y-cuando-sale-de-cartelera-3350628',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-recomendacion-de-un-abogado-para-conseguir-asilo-aun-con-el-decreto-de-biden-3350595',
#  'https://www.eltiempo.com/economia/sectores/juan-carlos-montenegro-es-el-quinto-director-que-tiene-el-invias-durante-el-gobierno-petro-3350631',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/estas-son-las-zonas-del-avion-donde-se-sienten-mas-las-turbulencias-segun-expertos-3350520',
#  'https://www.eltiempo.com/mundo/mas-regiones/que-es-el-consejo-de-seguridad-de-la-onu-y-para-que-sirve-cuatro-preguntas-y-respuestas-para-entender-este-organo-de-naciones-unidas-3350630',
#  'https://www.eltiempo.com/bogota/la-historia-tras-las-13-000-piezas-precolombinas-que-reposan-una-la-casa-de-un-marques-espanol-en-bogota-3348888',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/video-falcao-visito-condominio-en-chia-y-la-hinchada-de-millonarios-se-ilusiona-al-maximo-con-el-tigre-3350625',
#  'https://www.eltiempo.com/economia/sectores/habra-recorte-de-20-billones-de-pesos-en-el-presupuesto-dijo-el-ministro-de-hacienda-ricardo-bonilla-3350436',
#  'https://www.eltiempo.com/cultura/musica-y-libros/sorry-4-that-much-la-nueva-cancion-de-feid-3350627',
#  'https://www.eltiempo.com/cultura/gente/comer-chicle-ayuda-a-engordar-o-a-adelgazar-la-cara-expertos-responden-la-duda-3350622',
#  'https://www.eltiempo.com/cultura/gente/asi-luce-hoy-juan-carlos-villegas-presentador-de-tambien-caeras-y-no-me-lo-cambie-3350607',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/como-se-si-me-esta-dando-un-golpe-de-calor-las-senales-ante-la-ola-extrema-en-ee-uu-3350605',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/cbp-one-aun-funciona-ante-la-nueva-restriccion-de-asilo-de-joe-biden-3350593',
#  'https://www.eltiempo.com/bogota/cayo-en-cundinamarca-banda-de-dedicada-a-comercializar-peligrosa-droga-sus-efectos-podrian-ocasionar-cancer-de-pulmon-3350619',
#  'https://www.eltiempo.com/justicia/cortes/corte-constitucional-advierte-que-las-instituciones-educativas-no-pueden-retener-documentos-academicos-por-falta-de-pago-3350620',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-del-super-astro-sol-del-viernes-7-de-junio-de-3350413',
#  'https://www.eltiempo.com/bogota/vacaciones-escolares-de-mitad-de-ano-en-bogota-estas-son-las-fechas-de-receso-de-colegios-privados-y-distritales-para-2024-3350614',
#  'https://www.eltiempo.com/cultura/gente/que-significa-vestir-con-estos-colores-segun-expertos-3350600',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-dramatica-prediccion-de-mhoni-vidente-sobre-taylor-swift-ya-esta-embarazada-3350594',
#  'https://www.eltiempo.com/cultura/gente/le-robaron-su-celular-y-el-ladron-olvido-desconectar-la-cuenta-de-respaldo-los-hallazgos-fueron-insolitos-3350565',
#  'https://www.eltiempo.com/economia/sectores/a-gobierno-petro-le-quedan-dos-semanas-para-tener-la-creg-completa-antonio-jimenez-llenaria-1-de-5-vacantes-3350612',
#  'https://www.eltiempo.com/colombia/otras-ciudades/sicariato-en-ibague-un-hombre-que-caminaba-a-plena-luz-del-dia-por-el-barrio-el-salado-fue-abordado-por-un-sujeto-en-moto-3350597',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-ciudad-a-un-vuelo-de-nueva-york-que-paga-5-400-dolares-por-mudarse-alli-3350573',
#  'https://www.eltiempo.com/-805710',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/video-el-dardo-de-rafael-dudamel-a-carlos-antonio-velez-es-hablar-de-tonterias-3350260',
#  'https://www.eltiempo.com/tecnosfera/videojuegos/like-a-dragon-yakuza-una-serie-de-accion-y-crimen-adaptada-de-la-popular-franquicia-de-videojuegos-japonesa-3350596',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/el-restaurante-de-california-que-entro-en-la-lista-de-los-mejores-del-mundo-3350599',
#  'https://www.eltiempo.com/bogota/video-se-hizo-pasar-por-vendedor-de-bolsas-y-con-insolita-maniobra-se-robo-un-celular-en-una-cafeteria-al-norte-de-bogota-3350585',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/millonarios-suena-con-la-llegada-de-falcao-y-los-memes-ya-predicen-como-sera-su-etapa-en-bogota-3350610',
#  'https://www.eltiempo.com/justicia/cortes/carlos-carrillo-director-de-la-ungrd-asegura-que-olmedo-lopez-y-sneyder-pinilla-no-actuaron-solos-en-caso-de-los-carrotanques-3350608',
#  'https://www.eltiempo.com/cultura/gente/viuda-de-jota-mario-revela-videos-y-fotografias-del-presentador-de-muy-buenos-dias-5-anos-despues-de-su-muerte-3350196',
#  'https://www.eltiempo.com/cultura/gente/puente-festivo-y-dengue-si-va-a-tierra-caliente-tenga-cuidado-y-siga-estos-consejos-3350580',
#  'https://www.eltiempo.com/politica/gobierno/cancilleria-se-pronuncia-por-mercenarios-colombianos-muertos-en-ucrania-el-gobierno-no-promueve-ni-facilita-la-vinculacion-al-ejercito-de-ucrania-3350598',
#  'https://www.eltiempo.com/colombia/cali/video-caleno-asegura-en-video-que-fue-capturado-por-soldados-rusos-luego-de-ir-a-ucrania-3350584',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/boleteria-agotada-para-los-dos-partidos-de-la-final-de-la-liga-betplay-entre-santa-fe-y-bucaramanga-3350601',
#  'https://www.eltiempo.com/tecnosfera/apps/google-chrome-estos-son-los-videojuegos-gratis-que-tiene-el-navegador-y-sin-instalar-nada-3350575',
#  'https://www.eltiempo.com/cultura/gente/asi-es-el-ritual-a-base-de-romero-para-atraer-la-abundancia-y-la-fortuna-a-su-vida-3350592',
#  'https://www.eltiempo.com/cultura/gente/dia-del-padre-en-colombia-2024-estos-son-los-regalos-que-puede-comprar-por-menos-de-300-000-3350589',
#  'https://www.eltiempo.com/colombia/otras-ciudades/cartagena-rechazo-presunta-estafa-a-30-personas-y-acompanara-denuncias-en-la-fiscalia-3350540',
#  'https://www.eltiempo.com/mundo/europa/espana-asi-es-el-megaproyecto-en-madrid-para-construir-la-playa-urbana-mas-grande-de-europa-cuando-estara-lista-3350391',
#  'https://www.eltiempo.com/cultura/musica-y-libros/beyonce-reivindica-el-black-country-3333633',
#  'https://www.eltiempo.com/vida/viajar/la-ruta-de-las-series-la-experiencia-de-vivir-en-un-set-de-filmacion-3333635',
#  'https://www.eltiempo.com/politica/congreso/congreso-aprobo-proyecto-de-ley-de-canasta-basica-cultural-3350550',
#  'https://www.eltiempo.com/colombia/barranquilla/mako-el-robot-que-llega-a-una-clinica-de-barranquilla-para-asistir-en-cirugia-articular-de-rodilla-y-cadera-3350566',
#  'https://www.eltiempo.com/cultura/gente/las-cascaras-de-la-naranja-ayudan-a-mejorar-la-salud-del-corazon-3350562',
#  'https://www.eltiempo.com/cultura/gente/la-infusion-herbal-que-tonifica-los-musculos-de-la-vejiga-y-ayuda-a-la-incontinencia-urinaria-3350553',
#  'https://www.eltiempo.com/cultura/musica-y-libros/honrar-las-raices-juan-pablo-vega-reestrena-nada-personal-3341087',
#  'https://www.eltiempo.com/cultura/gente/jhonny-rivera-habla-de-la-posibilidad-de-tener-hijos-con-jenny-lopez-no-lo-descarto-3350586',
#  'https://www.eltiempo.com/justicia/delitos/exjefes-paramilitares-declararon-en-juicio-contra-chiquita-brands-en-estados-unidos-3350587',
#  'https://www.eltiempo.com/cultura/musica-y-libros/entrevista-la-alfombra-roja-de-los-caligaris-3349875',
#  'https://www.eltiempo.com/mundo/medio-oriente/onu-incluye-a-israel-en-la-lista-de-paises-que-violan-los-derechos-de-los-ninos-en-un-conflicto-3350568',
#  'https://www.eltiempo.com/cultura/musica-y-libros/reconocer-la-divinidad-que-habita-en-cada-persona-es-entender-mejor-a-dios-william-ospina-3350561',
#  'https://www.eltiempo.com/salud/que-es-la-cirugia-de-mohs-el-tratamiento-para-el-cancer-de-piel-que-tiene-mayor-tasa-de-curacion-y-pocos-lugares-realizan-3350531',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/inician-restricciones-en-la-frontera-de-juarez-y-ee-uu-ante-decreto-de-biden-3350581',
#  'https://www.eltiempo.com/deportes/futbol-internacional/gabigol-en-nuevo-escandalo-reportan-fiesta-de-24-horas-con-80-mujeres-e-incidentes-3350582',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/florida-ron-desantis-firmo-ley-que-castigaria-a-quienes-hagan-esto-en-la-carretera-3350571',
#  'https://www.eltiempo.com/colombia/cali/cali-este-es-el-chaman-que-enganaba-a-mujeres-con-supuestos-riegos-para-la-suerte-y-el-amor-las-encerraba-y-abusaba-de-ellas-3350579',
#  'https://www.eltiempo.com/bogota/como-reportar-un-arbol-a-punto-de-caer-o-en-mal-estado-en-bogota-3350450',
#  'https://www.eltiempo.com/politica/gobierno/asesinos-de-ninos-presidente-gustavo-petro-tras-inclusion-de-israel-en-lista-de-paises-que-violan-derechos-de-ninos-en-conflicto-3350572',
#  'https://www.eltiempo.com/justicia/investigacion/primicia-colombia-gana-otra-millonaria-demanda-por-la-prohibicion-de-la-mineria-en-paramo-de-santurban-3350576',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/amaranto-perea-vuelve-a-encender-el-debate-sobre-el-nivel-de-la-liga-betplay-y-la-seleccion-colombia-3350578',
#  'https://www.eltiempo.com/cultura/musica-y-libros/la-cantante-juliana-se-presentara-en-los-billboard-latin-women-2024-para-honrar-a-las-mujer-homenajeadas-3350523',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/california-y-texas-encabezan-la-lista-de-estados-con-mas-ataques-de-este-tipo-3350555',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-nueva-advertencia-climatica-en-florida-en-medio-de-la-ola-de-calor-en-ee-uu-3350570',
#  'https://www.eltiempo.com/economia/sector-financiero/esta-es-la-receta-para-que-el-credito-barato-llegue-a-los-negocios-populares-en-colombia-3350506',
#  'https://www.eltiempo.com/bogota/llevar-a-tu-mascota-al-trabajo-conoce-el-concurso-que-premia-a-empresas-que-promueven-el-bienestar-animal-3350533',
#  'https://www.eltiempo.com/cultura/gente/la-kombucha-es-buena-o-mala-para-la-salud-asi-impacta-su-bienestar-y-cuanto-debe-tomar-3350574',
#  'https://www.eltiempo.com/politica/proceso-de-paz/rodrigo-londono-rechazo-las-acusaciones-de-antonio-garcia-y-dijo-que-sus-palabras-ponen-en-riesgo-la-vida-de-los-firmantes-del-acuerdo-de-paz-3350558',
#  'https://www.eltiempo.com/cultura/gente/campanita-desafio-xx-sera-presentador-de-dia-a-dia-3350521',
#  'https://www.eltiempo.com/mundo/sunak-se-disculpa-por-haberse-marchado-antes-de-la-ceremonia-por-el-dia-d-esto-fue-lo-que-dijo-3350567',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/adamari-lopez-revelo-el-acuerdo-que-hubiese-firmado-con-toni-costa-es-lo-mejor-3350559',
#  'https://www.eltiempo.com/justicia/cortes/las-claves-del-nuevo-lio-de-armando-benedetti-en-la-corte-suprema-habria-beneficiado-a-empresa-de-euclides-torres-3350569',
#  'https://www.eltiempo.com/cultura/gente/video-avion-aterrizo-de-emergencia-con-400-pasajeros-a-bordo-luego-de-que-el-motor-se-incendiara-3350514',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/el-impresionante-cambio-fisico-de-fredy-guarin-hasta-falcao-garcia-reacciono-con-sorpresa-3350437',
#  'https://www.eltiempo.com/bogota/oportunidades-laborales-en-bogota-297-vacantes-disponibles-a-traves-de-talento-capital-3350543',
#  'https://www.eltiempo.com/cultura/gente/emiratos-arabes-construyo-300-islas-de-lujo-para-millonarios-y-ahora-estan-abandonadas-3350551',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/colombiana-en-ee-uu-dijo-que-es-lo-primero-que-se-preguntan-los-latinos-al-conocerse-3350508',
#  'https://www.eltiempo.com/politica/partidos-politicos/colombia-esta-mamada-de-esta-polarizacion-fajardo-tras-propuesta-de-ivan-duque-para-elecciones-de-2026-3350556',
#  'https://www.eltiempo.com/vida/educacion/universidad-nacional-en-que-consiste-la-constituyente-universitaria-que-propone-el-nuevo-rector-leopoldo-munera-3350560',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/iban-por-la-playa-de-texas-y-encontraron-un-tesoro-que-nunca-imaginaron-3350546',
#  'https://www.eltiempo.com/mundo/medio-oriente/control-absoluto-de-la-frontera-entre-gaza-3350552',
#  'https://www.eltiempo.com/colombia/barranquilla/air-e-conmina-al-gobierno-y-a-la-creg-a-lograr-acuerdos-para-que-pueda-darse-la-reduccion-del-10-en-tarifas-de-energia-en-estratos-1-2-y-3-3350527',
#  'https://www.eltiempo.com/bogota/ninas-desaparecidas-en-suba-en-bogota-drama-de-la-madre-567854',
#  'https://www.eltiempo.com/cultura/gente/adios-al-platano-la-fruta-desconocida-y-rica-en-potasio-que-ayuda-a-aliviar-la-resaca-3350302',
#  'https://www.eltiempo.com/vida/educacion/atrapados-en-la-periferia-las-brechas-de-calidad-que-afectan-la-educacion-del-pais-3350340',
#  'https://www.eltiempo.com/colombia/medellin/video-bus-perdio-control-y-rodo-contra-casa-en-bello-mujer-habria-perdido-sus-piernas-3350538',
#  'https://www.eltiempo.com/vida/ciencia/minciencias-y-fulbright-entregaron-40-becas-de-formacion-doctoral-en-estados-unidos-3350545',
#  'https://www.eltiempo.com/bogota/que-estaciones-de-transmilenio-tendra-el-tramo-de-la-avenida-68-avanza-la-megaobra-de-bogota-3350497',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-26-migrantes-hallados-en-texas-pagaron-esta-millonada-a-un-coyote-por-cruzar-3350513',
#  'https://www.eltiempo.com/justicia/delitos/alerta-policia-de-transito-confirma-que-este-ano-han-sido-sancionados-104-conductores-por-placas-adulteradas-gemeliadas-3350554',
#  'https://www.eltiempo.com/cultura/gente/cristina-hurtado-hablo-sobre-los-malos-habitos-alimenticios-que-enfrenta-durante-grabaciones-3350525',
#  'https://www.eltiempo.com/cultura/gente/lo-que-le-espera-este-fin-de-semana-segun-la-influencia-planetaria-de-su-ascendente-3350537',
#  'https://www.eltiempo.com/colombia/medellin/emergencia-en-exclusivo-edificio-de-el-poblado-en-medellin-un-ascensor-se-desplomo-en-un-piso-21-y-habria-dos-personas-heridas-3350468',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/francisca-lachapel-se-muda-a-su-nueva-casa-en-miami-asi-de-lujosa-es-3350522',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/copa-america-colombia-es-reconocida-como-una-de-las-10-mejores-selecciones-del-mundo-3350530',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-3-derechos-y-beneficios-que-tiene-con-una-green-card-y-quiza-no-sabia-3350536',
#  'https://www.eltiempo.com/cultura/gente/arandano-rojo-la-super-fruta-ideal-para-comer-antes-de-hacer-deporte-segun-cientificos-3350542',
#  'https://www.eltiempo.com/economia/sectores/a-causa-de-fuertes-lluvias-aes-colombia-detiene-la-operacion-de-la-central-hidroelectrica-chivor-3350535',
#  'https://www.eltiempo.com/mundo/medio-oriente/israel-tres-escenarios-que-podrian-tumbar-el-gobierno-de-benjamin-netanyahu-3350499',
#  'https://www.eltiempo.com/deportes/otros-deportes/aterrador-nocaut-deja-a-boxeador-convulsionando-suban-al-medico-video-3350539',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/chicago-las-8-mejores-cosas-para-hacer-durante-el-verano-3350150',
#  'https://www.eltiempo.com/colombia/barranquilla/se-reactivan-los-trabajos-de-ampliacion-del-emblematico-hospital-de-barranquilla-3350532',
#  'https://www.eltiempo.com/economia/sectores/minhacienda-anuncio-el-alza-que-tendra-el-precio-del-diesel-en-colombia-para-grandes-consumidores-3350541',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/alerta-por-los-ataques-a-latinos-en-esta-ciudad-de-estados-unidos-3350526',
#  'https://www.eltiempo.com/mundo/latinoamerica/adolescente-roba-caballo-y-choca-con-auto-en-argentina-3350529',
#  'https://www.eltiempo.com/mundo/venezuela/para-la-izquierda-no-es-rentable-seguir-sosteniendo-al-regimen-venezolano-3350334',
#  'https://www.eltiempo.com/cultura/entretenimiento/shakira-llego-a-barranquilla-por-la-delicada-hospitalizacion-de-su-padre-que-se-encuentrra-en-uci-3350485',
#  'https://www.eltiempo.com/bocas/soltaria-las-manos-del-volante-en-una-curva-ioniq-5-un-paseo-en-el-auto-fantastico-de-hyundai-3350402',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/video-disparaba-a-automoviles-al-azar-en-california-y-mato-a-un-hombre-3350488',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/buscan-en-nueva-york-trabajadores-sin-experiencia-por-sueldo-de-45-dolares-la-hora-3350501',
#  'https://www.eltiempo.com/vida/ciencia/asi-fue-la-llegda-a-la-estacion-espacial-internacional-de-la-primera-mision-espacial-tripulada-de-boeing-3350517',
#  'https://www.eltiempo.com/colombia/otras-ciudades/asesinatos-en-quindio-ofrecen-recompensa-de-30-millones-de-pesos-por-informacion-sobre-autores-del-crimen-de-agente-de-la-sijin-3350524',
#  'https://www.eltiempo.com/mundo/medio-oriente/la-inteligencia-de-estados-unidos-cree-que-israel-mantiene-en-el-limbo-la-salida-de-gaza-a-proposito-estas-serian-las-razones-3350519',
#  'https://www.eltiempo.com/cultura/gente/diana-angel-hablo-sobre-su-relacion-con-culotauro-quedo-en-el-pasado-se-reciben-hojas-de-vida-3350471',
#  'https://www.eltiempo.com/colombia/medellin/polemica-en-medellin-por-anuncio-de-entregar-un-hotel-a-jovenes-de-la-primera-linea-3350518',
#  'https://www.eltiempo.com/justicia/cortes/corte-suprema-abre-nueva-investigacion-contra-armando-benedetti-por-presunto-enriquecimiento-ilicito-de-servidor-publico-3350516',
#  'https://www.eltiempo.com/economia/finanzas-personales/valor-de-la-canasta-familiar-aumento-un-17-7-en-el-primer-trimestre-del-ano-3350511',
#  'https://www.eltiempo.com/deportes/futbol-internacional/la-dura-critica-de-un-jugador-de-la-premier-league-a-seleccion-de-la-copa-america-no-es-nada-profesional-jugar-ahi-3350515',
#  'https://www.eltiempo.com/cultura/gente/the-chosen-asi-puede-ver-gratis-la-cuarta-temporada-de-la-serie-de-la-vida-de-jesus-en-colombia-3350157',
#  'https://www.eltiempo.com/cultura/gente/que-significa-vv-cuando-las-personas-lo-ponen-en-tiktok-o-en-whatsapp-3350460',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/florida-la-batalla-legal-que-gano-ron-desantis-contra-la-corte-3350504',
#  'https://www.eltiempo.com/economia/finanzas-personales/es-veterano-de-las-fuerzas-militares-de-colombia-estos-son-sus-beneficios-segun-el-ministerio-de-defensa-3350421',
#  'https://www.eltiempo.com/colombia/otras-ciudades/valledupar-80-cantantes-del-folclor-vallenato-fueron-certificados-por-el-sena-3350510',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-dos-estados-que-podrian-darle-el-triunfo-a-trump-sobre-biden-segun-encuesta-3350475',
#  'https://www.eltiempo.com/justicia/cortes/las-razones-por-las-que-el-consejo-de-estado-tumbo-sancion-de-la-procuraduria-contra-kiko-gomez-exgobernador-de-la-guajira-3350512',
#  'https://www.eltiempo.com/tecnosfera/apps/destinos-y-preferencias-del-viajero-colombiano-segun-google-3350505',
#  'https://www.eltiempo.com/colombia/cali/como-es-conviven-los-detenidos-de-estaciones-de-policia-en-reducidas-celdas-con-un-hacinamiento-del-1-100-3348554',
#  'https://www.eltiempo.com/colombia/cali/tragico-accidente-en-el-norte-del-valle-un-motociclista-murio-en-el-siniestro-3350479',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/agente-inmobiliaria-en-ee-uu-muestra-una-casa-y-lo-que-encontro-adentro-la-aterro-3350455',
#  'https://www.eltiempo.com/justicia/delitos/quien-es-el-hombre-que-desde-la-carcel-esta-detras-de-amenazas-de-muerte-a-guardias-del-inpec-3350411',
#  'https://www.eltiempo.com/cultura/gente/asi-puede-mejorar-la-flexibilidad-y-movilidad-muscular-despues-de-los-50-anos-3350451',
#  'https://www.eltiempo.com/deportes/ciclismo/santiago-buitrago-sufre-en-la-cuarta-etapa-del-criterium-dauphine-primoz-roglic-nuevo-lider-3350502',
#  'https://www.eltiempo.com/justicia/investigacion/urgente-redada-entre-colombia-y-ee-uu-contra-el-narcotrafico-y-lavado-de-activos-deja-21-capturados-casas-de-cambio-en-la-mira-3350470',
#  'https://www.eltiempo.com/vida/educacion/cuales-son-los-beneficios-que-tiene-ser-egresado-del-sena-en-colombia-conozca-todo-lo-que-dese-ser-si-es-egresado-de-la-entidad-3350434',
#  'https://www.eltiempo.com/vida/medio-ambiente/colombia-vuelve-a-mejorar-en-el-indice-de-desempeno-ambiental-epi-aunque-esta-lejos-de-la-buena-posicion-ocupo-por-anos-3350403',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/las-2-ciudades-de-nueva-york-elegidas-entre-las-mas-sucias-de-estados-unidos-3349648',
#  'https://www.eltiempo.com/cultura/gente/jessica-cediel-presumio-que-conocio-a-will-smith-en-el-estreno-de-bad-boys-4-fan-numero-uno-3350507',
#  'https://www.eltiempo.com/economia/finanzas-personales/quienes-tienen-derecho-a-recibir-el-subsidio-familiar-en-2024-3349610',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/el-estado-de-ee-uu-donde-se-puede-vivir-bien-con-solo-los-pagos-del-seguro-social-3350493',
#  'https://www.eltiempo.com/deportes/bogota-y-medellin-seran-epicentro-del-festival-dream-team-arena-bora-bora-en-medio-de-la-copa-america-3350509',
#  'https://www.eltiempo.com/colombia/otras-ciudades/agua-10-mil-wayuu-de-manaure-son-beneficiados-con-modulo-de-agua-potable-3350487',
#  'https://www.eltiempo.com/cultura/musica-y-libros/recuperan-metraje-inedito-de-john-lennon-para-el-nuevo-videoclip-del-tema-you-are-here-3350489',
#  'https://www.eltiempo.com/colombia/medellin/emergencia-en-exclusivo-edificio-de-el-poblado-en-medellin-un-ascensor-se-desplomo-en-un-piso-21-y-habria-dos-personas-heridas-3350468',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/tesla-en-texas-cuando-gana-uno-de-los-mecanicos-3350483',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/atencion-hinchas-de-santa-fe-detalles-de-la-venta-de-boletas-de-la-final-para-los-no-abonados-3350389',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-propuesta-de-california-para-mantener-a-trabajadores-y-estudiantes-a-salvo-del-calor-3350459',
#  'https://www.eltiempo.com/economia/finanzas-personales/ramo-abrio-nuevas-ofertas-de-empleo-en-colombia-con-salarios-de-hasta-5-millones-asi-puede-aplicar-3350127',
#  'https://www.eltiempo.com/tecnosfera/novedades-tecnologia/mas-de-200-millones-de-latinos-siguen-sin-acceso-a-internet-movil-por-que-3350477',
#  'https://www.eltiempo.com/tecnosfera/apps/microsoft-openai-y-nvidia-seran-investigadas-por-practicas-antimonopolio-3350481',
#  'https://www.eltiempo.com/justicia/cortes/el-juez-del-tolima-que-cometio-violencia-institucional-contra-una-victima-de-violencia-intrafamiliar-que-clamaba-por-proteccion-3350498',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/ola-de-calor-rompe-record-en-estados-unidos-podrian-empeorar-las-temperaturas-3350444',
#  'https://www.eltiempo.com/tecnosfera/novedades-tecnologia/la-nueva-aplicacion-de-leica-para-iphone-que-hara-que-tome-fotos-de-otro-nivel-asi-funciona-la-herramienta-3350500',
#  'https://www.eltiempo.com/podcast/contraataque/primer-round-de-la-final-de-futbol-colombiano-bucaramanga-suena-con-sorprender-a-santa-fe-3350496',
#  'https://www.eltiempo.com/cultura/gente/beele-hablo-sobre-la-acusacion-de-su-esposa-camila-en-redes-por-infidelidad-que-respondio-3350480',
#  'https://www.eltiempo.com/bogota/esta-es-la-mujer-que-llegaria-a-liderar-la-sectaria-de-planeacion-de-bogota-tras-anuncio-de-cambios-en-el-gabinete-del-alcalde-carlos-fernando-galan-3350495',
#  'https://www.eltiempo.com/deportes/futbol-internacional/david-ospina-concentrado-en-la-seleccion-pero-piensa-en-su-futuro-nacional-es-una-gran-oportunidad-3350494',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-ciudad-de-texas-elegida-como-la-mas-sucia-de-estados-unidos-3348979',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-ciudad-de-california-elegida-entre-las-3-mas-sucias-de-estados-unidos-3348999',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/atletico-nacional-tiene-en-la-mira-a-un-goleador-colombiano-para-reforzarse-en-la-liga-quien-es-3350491',
#  'https://www.eltiempo.com/colombia/barranquilla/la-policia-reforzara-seguridad-en-malambo-para-proteger-a-comerciantes-de-las-extorsiones-y-las-amenazas-3350486',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/ron-desantis-firmo-una-ley-que-elimina-estas-multas-en-florida-3349264',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/quiere-trabajar-en-cbp-aqui-puede-encontrar-varias-opciones-de-empleo-3346875',
#  'https://www.eltiempo.com/vida/medio-ambiente/inundaciones-en-colombia-donde-son-mas-frecuentes-en-el-pais-y-cuando-es-probable-que-ocurran-3350484',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/claudia-sheinbaum-cual-fue-su-propuesta-para-los-indocumentados-3348969',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/estados-unidos-de-que-acusan-a-hunter-el-hijo-de-joe-biden-en-su-juicio-3350445',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-mhoni-vidente-para-el-fin-de-semana-del-8-y-9-de-junio-3350482',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/el-actor-george-clooney-hablo-con-joe-biden-para-defender-el-trabajo-juridico-de-su-esposa-sobre-gaza-3350461',
#  'https://www.eltiempo.com/economia/sectores/mas-de-10-5-billones-estan-en-juego-por-28-demandas-de-constructores-de-vias-contra-la-ani-3349837',
#  'https://www.eltiempo.com/cultura/gente/pulla-de-lina-tejeiro-a-su-ex-juan-duque-por-su-nueva-novia-si-tienen-la-oportunidad-de-ser-la-mujer-del-proceso-desaprovechenla-3350442',
#  'https://www.eltiempo.com/cultura/gente/pensaron-que-un-tiburon-estaba-acechando-a-su-comunidad-y-resulto-ser-un-pescado-muy-comun-con-un-enorme-tamano-3350464',
#  'https://www.eltiempo.com/cultura/cine-y-tv/el-pato-donald-cumple-90-anos-la-historia-del-iconico-personaje-de-disney-3350473',
#  'https://www.eltiempo.com/tecnosfera/videojuegos/juegos-de-ubisoft-llegan-a-dispositivos-apple-3350463',
#  'https://www.eltiempo.com/justicia/servicios/embajador-de-japon-a-colombia-entrega-equipo-para-desminado-humanitario-3350439',
#  'https://www.eltiempo.com/bogota/hoy-tenemos-mas-herramientas-para-entregar-resultados-alcalde-carlos-galan-en-el-acto-de-sancion-del-plan-de-desarrollo-de-bogota-3350432',
#  'https://www.eltiempo.com/politica/partidos-politicos/promueven-marchas-contra-el-gobierno-para-el-proximo-20-de-julio-esto-se-sabe-3350449',
#  'https://www.eltiempo.com/deportes/futbol-internacional/amaranto-perea-antes-del-partido-colombia-vs-ee-uu-el-equipo-que-elija-nestor-lorenzo-va-a-competir-bien-3350467',
#  'https://www.eltiempo.com/bogota/ingreso-minimo-garantizado-link-para-consultar-si-es-nuevo-beneficiario-del-subsidio-en-junio-3350462',
#  'https://www.eltiempo.com/mundo/latinoamerica/javier-milei-ordena-el-cierre-del-ministerio-de-la-mujer-en-argentina-tras-senalarlo-de-burocratico-ideologico-y-sin-resultados-3350428',
#  'https://www.eltiempo.com/bogota/conozca-los-servicios-a-los-que-puede-acceder-en-una-comisarias-de-familia-en-bogota-3350446',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-ciudad-de-nueva-jersey-que-esta-entre-las-5-mas-sucias-de-estados-unidos-3350443',
#  'https://www.eltiempo.com/colombia/otras-ciudades/fue-un-encuentro-obligado-que-yo-mismo-denuncie-ante-las-autoridades-alcalde-de-santa-marta-sobre-polemicas-fotos-con-camilo-3350247',
#  'https://www.eltiempo.com/unidad-investigativa/fiscal-del-caso-de-nicolas-petro-debera-apartarse-del-expediente-por-filtracion-de-interrogatorio-del-hijo-del-presidente-3350458',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-nino-prodigio-para-hoy-viernes-7-de-junio-3350457',
#  'https://www.eltiempo.com/cultura/gente/nuestra-vida-se-hace-un-infierno-solo-para-que-los-turistas-vivan-bien-denuncia-habitante-de-ibiza-3350398',
#  'https://www.eltiempo.com/colombia/otras-ciudades/carlos-pinedo-recibe-alivio-en-medio-de-tormenta-consejo-de-estado-lo-ratifico-como-alcalde-de-santa-marta-3350453',
#  'https://www.eltiempo.com/salud/eps-compensar-no-podra-retirarse-por-ahora-del-sistema-de-salud-superintendencia-no-estaria-estudiando-el-caso-3350447',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-mhoni-vidente-para-hoy-viernes-7-de-junio-3350452',
#  'https://www.eltiempo.com/salud/golpe-en-la-cabeza-sepa-determinar-cuando-se-trata-de-algo-grave-por-los-sintomas-3350456',
#  'https://www.eltiempo.com/cultura/arte-y-teatro/mamma-mia-el-musical-de-misi-que-no-se-puede-perder-estas-son-las-razones-3349929',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/falcao-y-millonarios-esta-es-la-hipotesis-del-equipo-para-superar-el-obstaculo-de-impuesto-al-patrimonio-para-el-fichaje-3350454',
#  'https://www.eltiempo.com/lecturas-dominicales/irreverente-salvaje-exuberante-y-desconocido-las-maravillas-del-momo-del-villar-en-la-casita-3350440',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/biden-ya-hizo-una-advertencia-de-lo-que-hara-si-su-hijo-hunter-resulta-culpable-en-el-juicio-3350435',
#  'https://www.eltiempo.com/cultura/cine-y-tv/la-mujer-que-inspiro-a-martha-en-baby-reindeer-demanda-con-170-millones-a-netflix-3350314',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/que-se-conmemora-el-19-de-junio-en-estados-unidos-y-como-se-festeja-3350422',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-nana-calistar-para-hoy-viernes-7-de-junio-3350448',
#  'https://www.eltiempo.com/bogota/once-parques-cerrados-viernes-7-de-junio-por-racionamiento-de-agua-en-bogota-3350423',
#  'https://www.eltiempo.com/cultura/gente/frutas-que-no-elevan-el-azucar-en-sangre-ideales-para-comenzar-el-dia-3350394',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-del-miloto-del-jueves-6-de-junio-de-3350405',
#  'https://www.eltiempo.com/colombia/cali/atencion-la-via-panamericana-entre-cali-y-jamundi-esta-cerrada-estas-son-las-razones-y-desvios-3350374',
#  'https://www.eltiempo.com/cultura/gente/cual-es-la-isla-mas-peligrosa-del-mundo-y-por-que-esta-clasificada-como-uno-de-los-destinos-prohibidos-para-los-humanos-3350438',
#  'https://www.eltiempo.com/bogota/sabe-que-son-los-ecobarrios-en-bogota-y-cuantos-hay-3350429',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/precio-del-dolar-en-mexico-a-cuanto-cotiza-hoy-7-de-junio-3350418',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultados-del-chontico-dia-y-noche-del-jueves-6-de-junio-de-3350399',
#  'https://www.eltiempo.com/bogota/un-carro-de-mariachis-se-incendio-esta-madrugada-en-bogota-es-el-segundo-en-menos-de-una-semana-le-contamos-3350409',
#  'https://www.eltiempo.com/vida/educacion/con-ganas-de-estudiar-gratis-la-universidad-javeriana-ofrece-cursos-de-formacion-virtual-y-masiva-3350426',
#  'https://www.eltiempo.com/colombia/santander/las-emociones-y-estrategias-que-llevara-a-las-canchas-el-atletico-de-bucaramanga-en-juego-con-santa-fe-3350390',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-super-astro-luna-del-jueves-6-de-junio-de-3350392',
#  'https://www.eltiempo.com/salud/beneficios-y-riesgos-de-consumir-bebidas-probioticas-en-verdad-controlan-el-estres-y-dan-energia-3350433',
#  'https://www.eltiempo.com/cultura/gente/rihanna-se-retiro-y-no-piensa-sacar-nueva-musica-detalle-en-su-ropa-levanta-especulaciones-3350420',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultados-de-el-paisita-dia-y-noche-del-jueves-6-de-junio-de-3350385',
#  'https://www.eltiempo.com/colombia/otras-ciudades/pico-y-placa-en-pereira-para-el-martes-11-de-junio-de-2024-3350377',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-de-el-sinuano-del-jueves-6-de-junio-de-3350380',
#  'https://www.eltiempo.com/bogota/planes-culturales-gratuitos-en-bogota-para-el-fin-de-semana-del-7-al-9-de-junio-3350415',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-walter-mercado-para-hoy-viernes-7-de-junio-3350400',
#  'https://www.eltiempo.com/cultura/gente/colombianos-probaron-comida-espanola-y-recibieron-duras-criticas-por-sus-reacciones-sabe-a-huevo-crudo-3350419',
#  'https://www.eltiempo.com/colombia/cali/en-cali-los-hombres-denuncian-mas-los-hurtos-asi-esta-el-panorama-de-uno-de-los-delitos-que-mas-aqueja-a-la-ciudadania-3349755',
#  'https://www.eltiempo.com/vida/viajar/este-fin-de-semana-inicia-la-temporada-alta-de-mitad-de-ano-se-espera-que-se-movilicen-16-486-463-pasajeros-desde-las-terminales-terrestres-y-21-215-000-desde-los-aeropuertos-3350427',
#  'https://www.eltiempo.com/justicia/cortes/comision-de-disciplina-judicial-profirio-cargos-contra-fiscal-mario-burgos-por-video-de-interrogatorio-a-nicolas-petro-3350424',
#  'https://www.eltiempo.com/colombia/otras-ciudades/por-que-la-procuraduria-les-abrio-pliego-de-cargos-a-siete-concejales-de-un-municipio-de-narino-3350417',
#  'https://www.eltiempo.com/colombia/medellin/capturan-a-presuntos-delincuentes-que-se-hicieron-pasar-por-extranjeros-para-atracar-a-un-guia-turistico-3350425',
#  'https://www.eltiempo.com/bogota/intensamente-2-y-trendy-lanzan-experiencia-gratuita-con-un-mundo-de-emociones-en-bogota-3350408',
#  'https://www.eltiempo.com/vida/viajar/avianca-reactiva-seis-rutas-internacionales-para-la-temporada-de-mitad-de-ano-cuales-son-3350414',
#  'https://www.eltiempo.com/cultura/gente/los-electrodomesticos-del-d1-y-del-ara-que-puede-comprar-por-menos-de-100-000-3350375',
#  'https://www.eltiempo.com/economia/empresas/los-motivos-por-los-que-nvidia-se-volvio-la-segunda-empresa-publica-mas-valiosa-de-ee-uu-3350359',
#  'https://www.eltiempo.com/politica/partidos-politicos/alejandro-gaviria-denuncia-amenazas-en-redes-llevan-asi-mas-de-una-semana-3350412',
#  'https://www.eltiempo.com/vida/religion/el-papa-dice-que-hay-una-libertad-mala-que-permite-a-los-ricos-explotar-a-los-pobres-3350416',
#  'https://www.eltiempo.com/bocas/la-historia-de-los-dias-inciertos-de-fonseca-como-barman-vendedor-de-enciclopedias-y-granjero-3349467',
#  'https://www.eltiempo.com/mundo/europa/por-que-rusia-acusa-a-francia-de-estar-dispuesta-a-participar-directamente-en-el-conflicto-de-ucrania-3350406',
#  'https://www.eltiempo.com/colombia/barranquilla/bajo-hermetismo-se-mantiene-el-estado-de-salud-del-papa-de-shakira-en-una-clinica-de-barranquilla-esto-es-lo-que-se-sabe-3350404',
#  'https://www.eltiempo.com/vida/medio-ambiente/el-calor-y-el-cambio-climatico-pone-en-riesgo-la-salud-mental-y-fisica-de-las-embarazadas-los-ninos-y-los-adultos-mayores-oms-3350410',
#  'https://www.eltiempo.com/deportes/futbol-internacional/lionel-messi-ve-a-colombia-muy-bien-para-la-copa-america-va-a-ser-una-copa-muy-igualada-3350407',
#  'https://www.eltiempo.com/bogota/estadio-el-campin-hoy-se-firma-el-contrato-que-le-dara-vida-a-la-app-del-nuevo-complejo-cultural-y-deportivo-en-bogota-3350376',
#  'https://www.eltiempo.com/vida/viajar/estas-son-las-ciudades-mas-visitadas-por-turistas-extranjeros-durante-el-2024-3350401',
#  'https://www.eltiempo.com/bogota/canales-para-denunciar-a-los-vecinos-ruidosos-en-bogota-3350386',
#  'https://www.eltiempo.com/mundo/europa/estados-unidos-aclara-que-permite-a-ucrania-usar-armas-en-territorio-de-rusia-pero-solo-cerca-de-la-frontera-3350396',
#  'https://www.eltiempo.com/cultura/gente/marcar-su-maleta-con-un-accesorio-puede-ser-un-grave-error-y-podria-no-llegar-al-vuelo-esto-dijo-trabajador-de-aeropuerto-3350370',
#  'https://www.eltiempo.com/bogota/cortes-de-luz-en-barrios-de-bogota-viernes-7-de-junio-de-2024-3350388',
#  'https://www.eltiempo.com/colombia/medellin/modelo-webcam-fue-hallada-muerta-en-su-vivienda-en-medellin-esto-se-sabe-del-caso-3350395',
#  'https://www.eltiempo.com/justicia/delitos/con-ayuda-del-fbi-cayeron-en-bogota-y-guaduas-6-supuestos-narcotraficantes-el-jefe-seria-alias-w-3350393',
#  'https://www.eltiempo.com/bogota/la-dramatica-historia-detras-de-la-nina-desaparecida-en-santa-marta-y-hallada-4-meses-despues-en-pagadiario-de-bogota-3350297',
#  'https://www.eltiempo.com/politica/gobierno/exclusivo-mas-de-122-000-personas-han-solicitado-acogerse-a-las-oficinas-de-movilidad-segura-en-colombia-3350384',
#  'https://www.eltiempo.com/salud/pilas-estos-son-los-cuatro-tipos-de-personas-que-no-deberian-tomar-cafe-bajo-ninguna-circunstancia-3350383',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/falcao-garcia-pillado-en-reconocido-restaurante-en-bogota-causa-sensacion-hinchas-de-millonarios-atentos-3350378',
#  'https://www.eltiempo.com/colombia/santander/pico-y-placa-en-bucaramanga-para-el-martes-11-de-junio-de-2024-3350381',
#  'https://www.eltiempo.com/apuestas-deportivas/pronosticos-eurocopa-3350379',
#  'https://www.eltiempo.com/mundo/medio-oriente/la-guerra-en-gaza-cumple-ocho-meses-cual-es-el-balance-de-las-victimas-hasta-ahora-y-que-se-sabe-de-la-tregua-3350373',
#  'https://www.eltiempo.com/colombia/medellin/pico-y-placa-en-medellin-para-el-martes-11-de-junio-de-2024-3350318',
#  'https://www.eltiempo.com/colombia/cali/pico-y-placa-en-cali-para-el-martes-11-de-junio-de-2024-3350371',
#  'https://www.eltiempo.com/bogota/pico-y-placa-en-bogota-para-el-martes-11-de-junio-de-2024-3350307',
#  'https://www.eltiempo.com/justicia/investigacion/estas-son-las-9-cuantiosas-demandas-internacionales-sobre-las-que-colombia-espera-laudos-en-los-proximos-meses-3350295',
#  'https://www.eltiempo.com/colombia/santander/es-persona-no-grata-en-bucaramanga-rafael-dudamel-responde-a-las-criticas-de-carlos-antonio-velez-3350263',
#  'https://www.eltiempo.com/colombia/barranquilla/cierran-puente-peatonal-a-pocos-metros-de-la-estructura-que-colapso-y-que-dejo-cuatro-muertos-en-soledad-atlantico-3350300',
#  'https://www.eltiempo.com/mundo/europa/combatiente-colombiano-en-ucrania-se-entrego-al-ejercito-ruso-no-quiero-morir-al-igual-que-mis-companeros-3350012',
#  'https://www.eltiempo.com/mundo/africa/mueren-al-menos-40-personas-en-un-asalto-cerca-de-la-capital-de-sudan-segun-activistas-3350367',
#  'https://www.eltiempo.com/podcast/el-cafe-de-hoy/el-juego-de-tronos-en-la-universidad-nacional-como-queda-la-autonomia-universitaria-3350361',
#  'https://www.eltiempo.com/mundo/medio-oriente/en-medio-de-tensiones-el-primer-ministro-de-israel-benjamin-netanyahu-hablara-ante-el-congreso-de-estado-unidos-3350365',
#  'https://www.eltiempo.com/colombia/otras-ciudades/lo-ultimo-temblor-de-magnitud-mayor-a-4-0-se-registro-en-colombia-en-la-madrugada-de-este-7-de-junio-3350366',
#  'https://www.eltiempo.com/cultura/musica-y-libros/maluma-y-blessd-lanzan-album-conjunto-para-quebrar-historia-del-genero-urbano-en-colombia-3350364',
#  'https://www.eltiempo.com/economia/finanzas-personales/loteria-de-bogota-y-quindio-conozca-los-resultados-y-numeros-ganadores-del-ultimo-sorteo-del-jueves-7-de-junio-3350333',
#  'https://www.eltiempo.com/cultura/musica-y-libros/j-balvin-arranca-una-nueva-etapa-de-la-mano-de-chencho-corleone-con-polvo-de-tu-vida-3350363',
#  'https://www.eltiempo.com/podcast/audiocolumnas-el-tiempo/audiocolumna-madame-butterfly-en-cine-colombia-por-martha-senn-3350360',
#  'https://www.eltiempo.com/politica/congreso/los-consultorios-sicologicos-comunitarios-son-una-realidad-senado-aprobo-en-cuarto-y-ultimo-debate-proyecto-de-ley-que-los-crea-3350293',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/donald-trump-los-nombres-que-suenan-para-ser-su-candidato-a-vicepresidente-de-estados-unidos-quienes-son-y-que-opciones-tienen-3350084',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/boeing-logra-lanzamiento-exitoso-de-su-primera-nave-tripulada-rumbo-a-la-eei-3349998',
#  'https://www.eltiempo.com/unidad-investigativa/ungrd-habla-vocero-de-firma-detras-de-millonario-contrato-de-maquinaria-amarilla-para-obras-en-la-guajira-3350337',
#  'https://www.eltiempo.com/cultura/gente/estudio-revela-si-los-perros-pueden-detectar-la-maldad-en-las-personas-3350141',
#  'https://www.eltiempo.com/cultura/gente/cuanto-gano-martha-bolanos-tras-su-paso-en-la-casa-de-los-famosos-esta-seria-la-millonaria-cifra-3350169',
#  'https://www.eltiempo.com/cultura/gente/avianca-cambia-su-color-por-uno-completamente-diferente-asi-se-ve-el-nuevo-avion-3350066',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/la-intimidad-de-la-reunion-de-falcao-con-los-directivos-de-millonarios-se-espera-humo-blanco-3350351',
#  'https://www.eltiempo.com/bogota/la-personeria-le-pone-la-lupa-al-problematico-contrato-de-reforzamiento-de-la-unidad-deportiva-el-salitre-3350284',
#  'https://www.eltiempo.com/politica/partidos-politicos/los-desafios-de-la-geopolitica-segun-mike-pence-ivan-duque-y-jose-luis-rodriguez-zapatero-3350209',
#  'https://www.eltiempo.com/colombia/santander/denuncian-masiva-estafa-en-reconocido-concesionario-de-carros-de-alta-gama-clientes-habrian-perdido-mas-de-600-millones-de-pesos-3350086',
#  'https://www.eltiempo.com/cultura/gente/martha-isabel-bolanos-confesion-ante-posibilidad-de-que-karen-sevillano-se-gane-la-casa-de-los-famosos-3350202',
#  'https://www.eltiempo.com/cultura/gente/cuantos-participantes-conformaran-la-placa-el-domingo-en-la-casa-de-los-famosos-colombia-3350345',
#  'https://www.eltiempo.com/economia/sectores/ministerio-de-hacienda-bloqueo-de-manera-parcial-el-presupuesto-de-las-entidades-del-estado-3350188',
#  'https://www.eltiempo.com/cultura/gente/soy-cirujano-plastico-y-estos-son-los-errores-en-la-rutina-de-skincare-que-envejecen-3350249',
#  'https://www.eltiempo.com/cultura/gente/campanita-se-convierte-en-el-nuevo-eliminado-de-el-desafio-xx-3350330',
#  'https://www.eltiempo.com/deportes/otros-deportes/impactante-jugador-de-chiefs-de-la-nfl-sufre-paro-cardiaco-y-el-entrenamiento-se-suspende-3350175',
#  'https://www.eltiempo.com/bogota/por-que-a-pesar-de-las-estrategias-en-bogota-aumentan-las-muertes-en-siniestros-viales-expertos-explican-las-razones-3350342',
#  'https://www.eltiempo.com/economia/sector-financiero/estas-son-las-claves-para-reactivas-la-economia-3350128',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/estados-unidos-le-pide-a-israel-que-sea-transparente-sobre-el-ataque-a-una-escuela-en-gaza-3350205',
#  'https://www.eltiempo.com/cultura/gastronomia/siempre-he-trabajado-con-ingredientes-colombianos-eso-me-da-mucho-orgullo-3350001',
#  'https://www.eltiempo.com/cultura/gente/alerta-y-otros-famosos-humoristas-colombianos-que-han-terminado-de-pelea-con-sabados-felices-3350165',
# ...
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/que-dijo-mexico-sobre-la-colaboracion-con-estados-unidos-para-controlar-la-frontera-3349753',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/el-importante-anuncio-de-una-cadena-de-supermercados-de-ee-uu-para-el-verano-3349720',
#  'https://www.eltiempo.com/salud/otra-eps-pide-su-retiro-voluntario-del-sistema-eps-salud-bolivar-envio-solicitud-a-la-supersalud-3349743',
#  'https://www.eltiempo.com/bogota/continua-emergencia-por-bajo-nivel-de-agua-en-embalses-de-bogota-alcalde-resalta-necesidad-de-mantener-medidas-de-racionamiento-3349657',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/tiene-83-anos-pero-luce-mas-joven-gracias-a-esta-medida-anti-envejecimiento-que-tomo-3349733',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/florida-planea-crear-un-sendero-en-esta-zona-que-conectara-seis-condados-distintos-3349707',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/trabajaba-con-eugenio-derbez-en-television-ahora-acomoda-carritos-en-el-super-3349721',
#  'https://www.eltiempo.com/deportes/futbol-internacional/golpe-a-la-millonaria-subasta-francia-incauta-el-balon-de-oro-del-mundial-robado-a-diego-armando-maradona-3349740',
#  'https://www.eltiempo.com/cultura/gente/es-la-dieta-mediterranea-la-clave-para-que-las-mujeres-vivan-mas-esto-dice-harvard-3349723',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/california-creyo-que-la-habia-ghosteado-pero-cuando-descubrio-la-verdad-quedo-devastada-3349370',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/florida-la-nueva-ley-de-ron-desantis-que-impacta-en-la-calidad-del-agua-3349675',
#  'https://www.eltiempo.com/cultura/gente/predicciones-astrologicas-los-signos-del-zodiaco-con-mas-suerte-3349732',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/que-puede-pasar-con-un-indocumentado-en-la-frontera-tras-la-nueva-medida-de-biden-3349739',
#  'https://www.eltiempo.com/deportes/futbol-internacional/en-vivo-siga-el-minuto-a-minuto-del-sorteo-de-la-copa-mundial-femenina-sub-20-en-colombia-3349670',
#  'https://www.eltiempo.com/deportes/futbol-internacional/calendario-de-la-seleccion-colombia-en-el-mundial-femenino-sub-20-fechas-y-sedes-3349736',
#  'https://www.eltiempo.com/deportes/otros-deportes/escandalo-recordista-mundial-dio-positivo-en-control-al-dopaje-y-recibe-fulminante-sancion-3349725',
#  'https://www.eltiempo.com/politica/partidos-politicos/cne-se-declaro-competente-para-investigar-la-campana-de-gustavo-petro-en-el-marco-del-caso-por-presunta-financiacion-irregular-3349718',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/que-ocurrio-con-la-imagen-de-donald-trump-tras-ser-declarado-culpable-segun-encuesta-3349735',
#  'https://www.eltiempo.com/salud/riesgos-de-automedicarse-con-farmacos-para-bajar-de-peso-3349713',
#  'https://www.eltiempo.com/colombia/otras-ciudades/nueva-embestida-del-rio-ariari-deja-una-decena-de-veredas-incomunicadas-3349727',
#  'https://www.eltiempo.com/cultura/gente/lady-noriega-confeso-una-de-las-razones-por-las-que-se-hizo-intervenciones-esteticas-en-el-rostro-3349696',
#  'https://www.eltiempo.com/economia/sectores/atlantico-busca-ser-el-centro-de-la-transicion-energetica-por-su-gran-potencial-solar-y-eolico-3349690',
#  'https://www.eltiempo.com/economia/sectores/lanzan-proyecto-que-seria-la-solucion-definitiva-para-el-suministro-de-agua-potable-en-la-guajira-3349716',
#  'https://www.eltiempo.com/justicia/cortes/el-jalon-de-oreja-de-la-corte-a-mintrabajo-por-tramite-sobre-invalidez-laboral-para-acceder-a-pension-3349726',
#  'https://www.eltiempo.com/colombia/otras-ciudades/corregimiento-de-apure-en-plato-magdalena-amanecio-bajo-el-agua-1500-damnificados-3349722',
#  'https://www.eltiempo.com/mundo/latinoamerica/javier-milei-asi-le-ha-ido-a-seis-meses-de-gobernar-argentina-con-logros-economicos-retos-sociales-y-grandes-enredos-politicos-3348977',
#  'https://www.eltiempo.com/tecnosfera/novedades-tecnologia/espana-penara-la-difusion-de-imagenes-falsas-de-contenido-sexual-generadas-con-ia-3349706',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/estados-unidos-otro-servicio-de-streaming-anuncio-un-aumento-en-sus-tarifas-3349682',
#  'https://www.eltiempo.com/colombia/cali/de-pelicula-hombres-armados-golpearon-al-dueno-de-un-vehiculo-cuando-conducia-y-luego-la-victima-se-arrojo-a-la-via-para-salvarse-3349634',
#  'https://www.eltiempo.com/tecnosfera/novedades-tecnologia/viaje-al-centro-de-una-casa-inteligente-asi-funcionan-los-ecosistemas-digitales-de-samsung-3349714',
#  'https://www.eltiempo.com/economia/finanzas-personales/mr-taxes-reacciono-ante-criticas-en-redes-sociales-que-aseguran-que-se-la-paso-haciendo-videos-3349699',
#  'https://www.eltiempo.com/cultura/gente/piscina-semiolimpica-en-bogota-en-la-que-podra-nadar-a-partir-de-los-6-100-la-hora-3349256',
#  'https://www.eltiempo.com/contenido-comercial/msc-yacht-club-redefiniendo-el-significado-de-crucero-de-lujo-3349382',
#  'https://www.eltiempo.com/cultura/gente/casa-de-128-metros-cuadrados-es-construida-en-10-dias-en-madrid-3349702',
#  'https://www.eltiempo.com/cultura/musica-y-libros/festival-cordillera-2024-un-fin-de-semana-de-musica-latina-con-juan-luis-guerra-y-fito-paez-conozca-los-artistas-que-se-presentaran-en-los-dos-dias-de-festividad-3349689',
#  'https://www.eltiempo.com/deportes/futbol-internacional/advertencia-de-la-fcf-estafadores-usan-falsos-patrocinadores-de-la-seleccion-colombia-para-enganar-a-los-aficionado-3349639',
#  'https://www.eltiempo.com/cultura/gente/esforzarse-por-ser-una-persona-amada-y-admirada-puede-ser-nocivo-para-la-salud-la-ciencia-lo-explica-3349711',
#  'https://www.eltiempo.com/tecnosfera/apps/whatsapp-se-actualiza-con-cambios-y-mejoras-en-llamadas-y-uso-de-la-inteligencia-artificial-3349697',
#  'https://www.eltiempo.com/colombia/barranquilla/el-municipio-del-atlantico-donde-los-comerciantes-decidieron-armarse-ante-la-ola-de-extorsiones-3349621',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/es-colombiana-y-bromeo-sobre-la-pregunta-clave-que-hace-cbp-al-llegar-a-estados-unidos-3349685',
#  'https://www.eltiempo.com/vida/ciencia/el-hallazgo-de-un-t-rex-adolescente-puede-revelar-porque-era-el-rey-de-los-dinosaurios-3349673',
#  'https://www.eltiempo.com/cultura/gente/oracion-al-sagrado-corazon-de-jesus-para-la-salud-de-nuestros-seres-queridos-3349660',
#  'https://www.eltiempo.com/deportes/futbol-internacional/la-fortuna-que-vale-el-bolso-con-el-que-messi-llego-a-la-concentracion-de-argentina-para-la-copa-america-3349672',
#  'https://www.eltiempo.com/justicia/cortes/corte-suprema-se-abstiene-de-imponer-medida-carcelaria-contra-yahir-acuna-actual-alcalde-de-sincelejo-3349700',
#  'https://www.eltiempo.com/cultura/gente/asi-funciona-el-gel-anticonceptivo-masculino-seria-el-mejor-metodo-para-los-hombres-3349669',
#  'https://www.eltiempo.com/tecnosfera/novedades-tecnologia/mintic-y-google-lanzan-10-000-becas-gratuitas-en-ia-y-ciberseguridad-con-alto-potencial-de-empleo-3349679',
#  'https://www.eltiempo.com/unidad-investigativa/el-local-ligado-a-esposa-e-hijo-de-congresista-liberal-que-termino-afectado-por-caso-de-corrupcion-de-las-marionetas-3349694',
#  'https://www.eltiempo.com/bogota/abiertos-los-turnos-de-esterilizaciones-gratuitas-para-perros-y-gatos-en-bogota-3349678',
#  'https://www.eltiempo.com/economia/sectores/supertransporte-anuncia-duras-sanciones-y-multas-a-quienes-paguen-por-no-ir-a-curso-para-reducir-comparendos-estas-son-3349655',
#  'https://www.eltiempo.com/mundo/europa/el-papa-recibe-a-la-seleccion-croata-a-10-dias-de-debutar-frente-a-espana-en-la-eurocopa-3349687',
#  'https://www.eltiempo.com/deportes/futbol-internacional/mundial-femenino-sub-20-colombia-2024-asi-quedaron-los-grupos-tras-el-sorteo-en-bogota-3349674',
#  'https://www.eltiempo.com/politica/partidos-politicos/cne-niega-las-tres-recusaciones-a-los-magistrados-en-caso-petro-por-presunta-financiacion-irregular-3349668',
#  'https://www.eltiempo.com/apuestas-deportivas/casas-de-apuestas/betplay-bono-de-bienvenida-3324533',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/hunter-biden-quien-es-y-a-que-se-dedica-su-esposa-3349662',
#  'https://www.eltiempo.com/justicia/cortes/gobierno-sufre-nuevo-reves-en-las-altas-cortes-suspenden-norma-que-permitia-firmar-convenios-directos-con-acciones-comunales-3349683',
#  'https://www.eltiempo.com/cultura/gente/que-paso-con-beele-y-la-venezolana-isabella-ladino-camila-rodriguez-esposa-del-cantante-de-loco-revelo-detalles-de-supuesta-infidelidad-3349279',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/decenas-de-pasajeros-se-enfermaron-al-mismo-tiempo-durante-un-vuelo-a-texas-que-paso-3349628',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/joe-biden-cerro-la-frontera-no-esto-significa-realmente-su-nueva-medida-de-asilo-3349667',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/la-exclusiva-zona-de-miami-donde-se-alojara-messi-para-la-copa-america-2024-3349645',
#  'https://www.eltiempo.com/economia/sector-financiero/no-publicar-tenemos-un-lento-crecimiento-en-2024-pero-se-viene-un-ano-de-normalizacion-en-2025-bbva-3347803',
#  'https://www.eltiempo.com/vida/ciencia/el-ruso-oleg-kononenko-el-primer-hombre-en-alcanzar-los-1-000-dias-en-el-espacio-3349656',
#  'https://www.eltiempo.com/cultura/gente/fotos-cambio-fisico-de-miss-universe-colombia-daniela-toloza-llego-a-pesar-106-kilos-3349643',
#  'https://www.eltiempo.com/deportes/ciclismo/criterium-dauphine-2024-santiagio-buitrago-vuela-en-la-contrarreloj-individual-resumen-etapa-4-3349664',
#  'https://www.eltiempo.com/economia/finanzas-personales/estos-son-los-casos-en-los-que-el-inquilino-debe-pagar-al-arrendador-una-indemnizacion-segun-la-ley-3349658',
#  'https://www.eltiempo.com/salud/los-graves-riesgos-de-no-tratar-lal-sifilis-una-enfermedad-de-transmision-sexual-que-no-para-de-crecer-3349601',
#  'https://www.eltiempo.com/cultura/gente/greeicy-anuncia-nuevas-fechas-para-su-tour-mundial-2024-donde-y-cuando-verla-3349666',
#  'https://www.eltiempo.com/cultura/gente/esta-es-la-forma-correcta-de-consumir-avena-para-aumentar-la-masa-muscular-3349642',
#  'https://www.eltiempo.com/vida/ciencia/la-extrana-mancha-en-el-sol-que-preocupa-en-la-tierra-es-responsable-de-poderosas-llamaradas-3349647',
#  'https://www.eltiempo.com/cultura/musica-y-libros/marc-anthony-inicia-su-gira-europea-historia-tour-con-un-espectacular-concierto-en-las-palmas-3349663',
#  'https://www.eltiempo.com/bogota/los-eventos-de-junio-en-el-jardin-botanico-de-bogota-3349652',
#  'https://www.eltiempo.com/colombia/barranquilla/capturan-en-barranquilla-a-alias-el-menor-otro-de-los-cabecillas-de-las-autodefensas-conquistadoras-de-la-sierra-nevada-3349653',
#  'https://www.eltiempo.com/cultura/gente/estos-son-los-privilegios-que-ofrece-a-la-gente-dinamarca-el-pais-mas-feliz-del-mundo-3349579',
#  'https://www.eltiempo.com/cultura/gente/el-poder-secreto-de-la-cascara-de-la-naranja-desde-bajar-de-peso-hasta-combatir-enfermedades-3349641',
#  'https://www.eltiempo.com/politica/partidos-politicos/senador-jota-pe-hernandez-responde-a-senalamientos-sobre-supuesto-montaje-en-su-visita-a-el-salvador-para-posesion-de-nayib-bukele-3349654',
#  'https://www.eltiempo.com/deportes/futbol-internacional/esta-es-la-nueva-camiseta-del-real-madrid-que-ya-modela-linda-caicedo-sera-la-primera-de-mbappe-3349651',
#  'https://www.eltiempo.com/cultura/musica-y-libros/la-cantante-halsey-anuncia-que-tiene-lupus-y-leucemia-en-su-nueva-cancion-the-end-tengo-suerte-de-estar-viva-3349631',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/el-duro-enfrentamiento-que-tuvo-garrett-ziegler-con-la-esposa-de-hunter-biden-en-el-juicio-3349627',
#  'https://www.eltiempo.com/vida/religion/oracion-a-la-sangre-de-cristo-para-pedir-proteccion-y-solucion-a-los-casos-dificiles-3349649',
#  'https://www.eltiempo.com/bogota/en-video-asi-fue-como-los-bomberos-rescataron-a-un-perrito-atrapado-en-una-alcantarilla-en-suba-3349630',
#  'https://www.eltiempo.com/cultura/gente/luna-de-fresa-2024-significado-fecha-y-como-ver-este-fenomeno-3349640',
#  'https://www.eltiempo.com/vida/medio-ambiente/descubren-una-nueva-especie-de-orquidea-en-el-parque-nacional-natural-purace-3349650',
#  'https://www.eltiempo.com/economia/finanzas-personales/app-de-bancolombia-el-banco-lamento-las-fallas-presentadas-y-hablo-del-dinero-de-sus-clientes-3349633',
#  'https://www.eltiempo.com/mundo/medio-oriente/revelan-audios-de-uno-de-los-rehenes-argentinos-en-gaza-siendo-secuestrados-por-hamas-3349606',
#  'https://www.eltiempo.com/cultura/gente/este-es-el-pais-que-puede-desaparecer-por-el-cambio-climatico-3349620',
#  'https://www.eltiempo.com/colombia/otras-ciudades/muerte-en-cholon-hoy-es-el-sepelio-del-joven-que-murio-destrozado-por-helice-de-yate-3349614',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/las-aranas-capaces-de-volar-que-llegaran-este-verano-a-nueva-york-y-nueva-jersey-3349624',
#  'https://www.eltiempo.com/cultura/gente/asi-es-la-casa-de-cristiano-ronaldo-y-georgina-rodriguez-en-arabia-saudita-3349468',
#  'https://www.eltiempo.com/mundo/venezuela/chavismo-confirma-que-ee-uu-ofrecio-incentivos-a-nicolas-maduro-para-que-dejara-el-poder-que-ofrecio-3349429',
#  'https://www.eltiempo.com/deportes/futbol-colombiano/hugo-rodallega-calienta-la-final-de-liga-betplay-entre-santa-fe-y-bucaramanga-3349638',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/en-este-estado-de-ee-uu-sera-la-gente-quien-tome-decisiones-sobre-los-indocumentados-3349612',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-nino-prodigio-para-hoy-miercoles-5-de-junio-3349637',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/ayudo-a-azafata-a-limpiar-un-accidente-de-popo-en-el-avion-y-recibio-una-recompensa-3349607',
#  'https://www.eltiempo.com/mas-contenido/atencion-en-salud-y-bienestar-una-dupla-que-transforma-vidas-3349636',
#  'https://www.eltiempo.com/politica/gobierno/presidente-petro-anuncia-reestructuracion-de-la-ungrd-luego-de-que-justicia-conozca-la-informacion-de-la-entidad-3349619',
#  'https://www.eltiempo.com/mundo/como-se-demuestra-solvencia-economica-en-colombia-para-la-visa-a-estados-unidos-o-canada-le-contamos-3349635',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-nana-calistar-para-hoy-miercoles-5-de-junio-3349632',
#  'https://www.eltiempo.com/colombia/otras-ciudades/extorsiones-y-trafico-de-estupefacientes-la-actividad-de-un-call-center-criminal-al-interior-de-carcel-de-girardot-3349623',
#  'https://www.eltiempo.com/mundo/eeuu-y-canada/los-horoscopos-de-mhoni-vidente-para-hoy-miercoles-5-de-junio-3349625',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-de-miloto-del-martes-4-de-junio-de-3349604',
#  'https://www.eltiempo.com/bogota/atencion-bogota-puente-de-la-avenida-68-con-calle-3-sera-entregado-en-agosto-conozca-todos-los-detalles-y-los-beneficios-que-traera-a-la-capital-3349357',
#  'https://www.eltiempo.com/justicia/investigacion/procuraduria-advierte-que-reforma-pensional-no-sera-viable-si-no-se-revisa-su-implementacion-3349626',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultados-del-chontico-dia-y-noche-del-martes-4-de-junio-de-3349586',
#  'https://www.eltiempo.com/mundo/medio-oriente/wolrd-central-kitchen-regresa-a-gaza-y-entrega-50-millones-de-alimentos-tras-ataque-a-voluntarios-3349584',
#  'https://www.eltiempo.com/politica/gobierno/andrea-petro-se-refiere-a-posibilidad-de-reeleccion-de-gustavo-petro-dejen-el-show-3349575',
#  'https://www.eltiempo.com/economia/finanzas-personales/resultado-del-super-astro-luna-del-martes-4-de-junio-de-3349572',
#  'https://www.eltiempo.com/politica/proceso-de-paz/alias-calarca-del-emc-ve-dificil-que-el-presidente-petro-pueda-lograr-la-paz-total-y-explica-razones-3349617',
#  'https://www.eltiempo.com/colombia/cali/emergencia-por-incendio-de-buseta-de-transporte-de-servicio-publico-en-cali-3349565',
#  'https://www.eltiempo.com/colombia/otras-ciudades/exdefensora-de-familia-finalmente-es-condenada-por-el-caso-de-fundacion-peces-vivos-infame-maltrato-de-menores-en-ibague-3349360',
#  'https://www.eltiempo.com/cultura/gente/empleada-de-hotel-revela-cuales-son-los-objetos-que-jamas-limpian-en-las-habitaciones-3349616',
#  ...]

# %% [markdown]
# **Ejercicio 3** (10 min)
#
# Extraiga la información de las primeras 100 noticias y continue con la información en un dataframe  usando los feeds:

# %% [markdown]
# Mira el siguiente código

# %%
import concurrent.futures
import time
import random

# Función que simula la descarga de contenido de una URL
def download_content(url):
    # Simula la duración de la descarga
    download_duration = 10
    print(f"Descargando desde {url} (duración: {download_duration} segundos)")
    time.sleep(download_duration)
    return f"Contenido de {url} descargado."

# Lista de URLs ficticias
urls = [
    "http://sitio1.com/data",
    "http://sitio2.com/data",
    "http://sitio3.com/data",
    "http://sitio4.com/data",
    "http://sitio5.com/data"
]

# Usamos ThreadPoolExecutor para descargar el contenido de las URLs en paralelo
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Mapeamos la función 'download_content' a cada URL
    results = list(executor.map(download_content, urls))

# Imprimimos los resultados
for result in results:
    print(result)
# Out:
# Descargando desde http://sitio1.com/data (duración: 10 segundos)Descargando desde http://sitio2.com/data (duración: 10 segundos)
# Descargando desde http://sitio3.com/data (duración: 10 segundos)
# Descargando desde http://sitio4.com/data (duración: 10 segundos)
# Descargando desde http://sitio5.com/data (duración: 10 segundos)
#
# Contenido de http://sitio1.com/data descargado.
# Contenido de http://sitio2.com/data descargado.
# Contenido de http://sitio3.com/data descargado.
# Contenido de http://sitio4.com/data descargado.
# Contenido de http://sitio5.com/data descargado.

# %%
import os
num_cpus = os.cpu_count()
print(f"Número de CPUs disponibles: {num_cpus}")
# Out:
# Número de CPUs disponibles: 2

# %% [markdown]
# El método `ThreadPoolExecutor.map` del módulo `concurrent.futures` en Python es una herramienta poderosa para ejecutar operaciones en paralelo. Es especialmente útil cuando tienes una función que quieres ejecutar con diferentes argumentos de manera concurrente. Aquí te doy una clase sobre cómo funciona `ThreadPoolExecutor.map` y cómo se usa en el contexto de tu script:
#
# ### 1. ¿Qué es `ThreadPoolExecutor`?
#
# `ThreadPoolExecutor` es una clase en el módulo `concurrent.futures` que proporciona una interfaz de alto nivel para ejecutar llamadas a funciones de manera asincrónica (es decir, de forma paralela o concurrente). Utiliza un pool de hilos (threads) para ejecutar las llamadas a funciones, lo que permite realizar múltiples operaciones al mismo tiempo.
#
# ### 2. ¿Qué hace el método `.map`?
#
# El método `.map` es similar al `map` integrado de Python, pero está diseñado para ejecutar las funciones en paralelo utilizando el pool de hilos de `ThreadPoolExecutor`. Lo que hace es tomar una función y un iterable (como una lista), y luego aplicar esa función a cada elemento del iterable. La gran ventaja aquí es que cada llamada a la función se ejecuta en un hilo separado, lo que permite que las operaciones se realicen de manera concurrente.
#
# ### 3. ¿Cómo funciona en tu script?
#
# En tu script, `ThreadPoolExecutor.map` se utiliza para aplicar la función `download_content` a cada URL en la lista `urls`. Esto es lo que sucede:
#
# - **Inicialización**: `ThreadPoolExecutor` se inicializa utilizando el bloque `with`, lo que garantiza que todos los hilos se cierren correctamente al finalizar las operaciones.
#
# - **Aplicación de la Función**: `executor.map(download_content, urls)` aplica `download_content` a cada elemento en `urls`. Bajo el capó, `ThreadPoolExecutor` asigna cada llamada a la función a un hilo diferente en su pool de hilos.
#
# - **Ejecución Concurrente**: Las funciones se ejecutan en paralelo. Si tienes, por ejemplo, 5 URLs y un pool de 5 hilos, las 5 descargas podrían, en teoría, suceder al mismo tiempo.
#
# - **Recopilación de Resultados**: `executor.map` devuelve un iterador que se convierte en una lista. Los resultados se devuelven en el orden en que se pasaron las tareas, es decir, el primer resultado corresponde al primer elemento en `urls`, y así sucesivamente.
#
# - **Impresión de Resultados**: Al final, imprimes los resultados, que son los valores devueltos por `download_content` para cada URL.
#
# ### 4. Ventajas de usar `ThreadPoolExecutor.map`
#
# - **Concurrencia**: Permite realizar múltiples operaciones de I/O (como solicitudes de red) de manera más eficiente, ya que no estás esperando a que cada operación se complete antes de iniciar la siguiente.
#
# - **Facilidad de Uso**: Proporciona una forma sencilla de convertir un bucle que procesa elementos de manera secuencial en un conjunto de operaciones concurrentes, con mínimos cambios en el código.
#
# - **Gestión de Recursos**: El manejo de los hilos y su ciclo de vida se gestionan automáticamente, lo que reduce el riesgo de errores relacionados con la concurrencia.

# %% [markdown]
# ¿Y esto en qué ayuda?

# %%
# Función para procesar cada feed
def fetch_feed_data(sitemap_url):
  respuesta = requests.get(sitemap_url)

  try:
    soup = BeautifulSoup(respuesta.content, 'html.parser')
    feed_response = requests.get(enlace)

    if feed_response.status_code == 200:
      title_tag = soup.find('h1').get_text()
      author_tag = soup.find('a', class_='c-detail__author__name').get_text()
      date_tag = soup.find('time').get_text()
      content_tags = soup.find_all('div', class_='paragraph')
      content = ' '.join([p.get_text() for p in content_tags])
      return(title_tag,date_tag,author_tag,content ,sitemap_url )
  except:
      None
  return None

# %%
fetch_feed_data('https://www.eltiempo.com/cultura/gente/asi-luce-hoy-juan-carlos-villegas-presentador-de-tambien-caeras-y-no-me-lo-cambie-3350607')
# Out:
# ("Así luce hoy Juan Carlos Villegas, presentador de 'También caerás' y 'No me lo cambie'",
#  'junio 7 de 2024, 03:25 P.M.',
#  'Karen Dahiana Lopez Castañeda',
#  "(Le podría interesar: Esta es la enfermedad que padece Amador Padilla, expresentador de Bravíssimo internado en UCI). Omar Murillo, exparticipante de 'La casa de los famosos', hizo parte de este equipo por varios años, de esa manera, el hombre ganó fama a nivel nacional. El formato estuvo al aire por casi 15 años y, otra de las figuras que es recordada por muchos de los televidentes es Juan Carlos Villegas. El hombre hizo parte del formato en varias temporadas y se desempeñó en diferentes roles como presentador y con personajes de humor. (Lea también: Presentador estadounidense compró un apartamento y se encontró una gran sorpresa en el techo). De acuerdo con información vista en la página web de 'Caracol Televisión', el hombre era empírico de los medios de comunicación, pero logró destacar en la presentación y la locución, desde 1994 con el programa 'No me lo cambie'. Luego de que 'También caerás' saliera del aire, Villegas se fue a vivir a Pereira junto a su esposa y sus tres hijos:\xa0Germán Daniel, María Alejandra y Juanita. No se sabe mucho sobre su vida actualmente, en redes sociales se aprecia que es bastante reservado, pues no cuenta detalles personales, pero sí sube fotografías junto a sus hijos, viajes, y tiene algunas viejas instantáneas posando con artistas famosos como J Balvin,\xa0Eugenio Derbez o Falcao García. (No deje de leer: Esposa de Amador Padilla, expresentador de Bravíssimo, revela que él está muy delicado en UCI: 'Las plaquetas se le bajaron mucho'). KAREN CASTAÑEDAREDACCIÓN ALCANCE DIGITALEL TIEMPO Puente festivo y dengue: si va a tierra caliente, tenga cuidado y siga estos consejos 'Campanita', exparticipante del 'Desafío XX', se estrenará como presentador: este es el programa en el que trabajará Así puede mejorar la flexibilidad y movilidad muscular después de los 50 años",
#  'https://www.eltiempo.com/cultura/gente/asi-luce-hoy-juan-carlos-villegas-presentador-de-tambien-caeras-y-no-me-lo-cambie-3350607')

# %%
# %%time
# Paralelizar las solicitudes
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
    results = list(executor.map(fetch_feed_data, sitemap_urls[0:10]))



# Crear DataFrame
column_names = ["Titulo", "Fecha","Autor", "Contenido", "Url"]
df = pd.DataFrame(results, columns=column_names)
# Out:
# CPU times: user 3.82 s, sys: 95.3 ms, total: 3.91 s
# Wall time: 4.12 s

# %%
# %%time
# Paralelizar las solicitudes
with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
    results = list(executor.map(fetch_feed_data, sitemap_urls[0:10]))



# Crear DataFrame
column_names = ["Titulo", "Fecha","Autor", "Contenido", "Url"]
df = pd.DataFrame(results, columns=column_names)
# Out:
# CPU times: user 3.38 s, sys: 62.3 ms, total: 3.44 s
# Wall time: 4.33 s

# %%
df
# Out:
#                                               Titulo  \
# 0  Infraestructura de primer nivel y clima favora...
# 1  EN VIVO | Movilidad en Bogotá: se reportan man...
# 2  Urgente: escalada terrorista contra la Policía...
# 3  Estos son los importantes negocios de 'Ceta' y...
# 4  Mujer terminó golpeada y sin pertenencias desp...
# 5  Chile estaría atravesando una crisis antes de ...
# 6  Región metropolitana: municipio de Chía da un ...
# 7  Lo último: reportan una fuerte explosión en el...
# 8  Al menos un estudiante muerto y otro herido tr...
# 9  Fuad Char reveló cuáles serían los dos primero...
#
#                          Fecha                             Autor  \
# 0  junio 7 de 2024, 05:50 P.M.                  Flor Díaz Ospino
# 1  junio 7 de 2024, 05:48 P.M.        redacción últimas noticias
# 2  junio 7 de 2024, 05:48 P.M.             Alicia Liliana Méndez
# 3  junio 7 de 2024, 05:48 P.M.        Wendys Loraine Pitre Ariza
# 4  junio 7 de 2024, 05:47 P.M.         Vanessa Perez Castellanos
# 5  junio 7 de 2024, 05:44 P.M.            Harold Yepes Izquierdo
# 6  junio 7 de 2024, 05:43 P.M.                 Guillermo Reinoso
# 7  junio 7 de 2024, 05:34 P.M.       Jose Antonio Minota Hurtado
# 8  junio 7 de 2024, 05:30 P.M.                         afp y efe
# 9  junio 7 de 2024, 05:18 P.M.  Sergio Andres Gamboa Mendivielso
#
#                                            Contenido  \
# 0  Las cifras avalan el posicionamiento de Barran...
# 1  Por otra parte, viajeros pueden empezar a sali...
# 2  El primer ataque se registro sobre las 4:30 de...
# 3  (Más noticias: Kratos coquetea con María Ferna...
# 4  De acuerdo con el informe de City Tv, la mujer...
# 5  Estados Unidos, sede de la Copa América 2024, ...
# 6  Chía es la segunda entidad territorial de la S...
# 7  Las autoridades se dirigen al lugar de los hec...
# 8  El suceso, inédito en el país centroamericano,...
# 9  Lea también: Para Óscar Córdoba no es momento ...
#
#                                                  Url
# 0  https://www.eltiempo.com/colombia/barranquilla...
# 1  https://www.eltiempo.com/bogota/en-vivo-movili...
# 2  https://www.eltiempo.com/justicia/conflicto-y-...
# 3  https://www.eltiempo.com/cultura/gente/estos-s...
# 4  https://www.eltiempo.com/bogota/mujer-termino-...
# 5  https://www.eltiempo.com/deportes/futbol-inter...
# 6  https://www.eltiempo.com/bogota/region-metropo...
# 7  https://www.eltiempo.com/colombia/cali/lo-ulti...
# 8  https://www.eltiempo.com/mundo/latinoamerica/a...
# 9  https://www.eltiempo.com/deportes/futbol-colom...

# %%
from IPython.display import YouTubeVideo

# ID del video de YouTube
video_id = "uNz9-99ylMQ"

# Embeber el video
YouTubeVideo(video_id)

# %%
def measure_execution_time(max_workers):
    start_time = time.time()
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        results = list(executor.map(fetch_feed_data, sitemap_urls[0:10]))
    duration = time.time() - start_time
    return duration

# Probar diferentes números de hilos
num_workers_list = [1, 2, 4, 8, 16]
execution_times = {}

for num_workers in num_workers_list:
    duration = measure_execution_time(num_workers)
    execution_times[num_workers] = duration
    print(f"Con {num_workers} hilos, la ejecución tomó {duration:.2f} segundos")
# Out:
# Con 1 hilos, la ejecución tomó 4.26 segundos
# Con 2 hilos, la ejecución tomó 3.38 segundos
# Con 4 hilos, la ejecución tomó 7.62 segundos
# Con 8 hilos, la ejecución tomó 3.82 segundos
# Con 16 hilos, la ejecución tomó 3.08 segundos

# %% [markdown]
# ##**Algo más**
#
# ### **Introducción a Hugging Face**
#
# Hugging Face es una empresa y comunidad líder en el campo del Procesamiento del Lenguaje Natural (NLP). Fundada en 2016, su misión es democratizar el acceso a modelos avanzados de NLP, facilitando su uso y aplicación en diversas industrias. La compañía es conocida principalmente por su biblioteca `transformers`, que ha revolucionado la forma en que desarrolladores e investigadores trabajan con modelos de NLP.
#
# ### **Biblioteca `transformers`**
#
# La biblioteca `transformers` de Hugging Face es una herramienta de código abierto que proporciona acceso a una amplia gama de modelos preentrenados para tareas de NLP. Estos modelos incluyen algunos de los más avanzados y populares en el campo, como BERT, GPT-3, RoBERTa, T5, y muchos otros.
#
# #### **Características Principales**
#
# 1. **Modelos Preentrenados**: La biblioteca incluye miles de modelos preentrenados que se pueden usar directamente para tareas específicas como clasificación de texto, generación de texto, traducción, resumen, entre otros.
#
# 2. **Facilidad de Uso**: Los modelos se pueden integrar fácilmente con unas pocas líneas de código, lo que reduce significativamente el tiempo y el esfuerzo necesarios para implementar soluciones de NLP.
#
# 3. **Adaptabilidad**: Además de usar modelos preentrenados, `transformers` permite ajustar los modelos a datos específicos para tareas personalizadas a través de técnicas de fine-tuning.
#
# 4. **Compatibilidad con PyTorch y TensorFlow**: La biblioteca es compatible tanto con PyTorch como con TensorFlow, dos de los frameworks más populares para aprendizaje profundo.
#
# 5. **Comunidad Activa**: Hugging Face tiene una comunidad vibrante que contribuye constantemente al desarrollo de la biblioteca, comparte modelos y proporciona soporte a través de foros y redes sociales.
#
# ### **Componentes Clave**
#
# 1. **Modelos**: Los modelos en `transformers` son la piedra angular de la biblioteca. Están diseñados para ser fácilmente intercambiables y permiten a los usuarios elegir el modelo que mejor se adapte a sus necesidades.
#
# 2. **Tokenizers**: Los tokenizers son herramientas que convierten texto en números, el formato que los modelos pueden procesar. Hugging Face proporciona diferentes tokenizers optimizados para diversos modelos y tareas.
#
# 3. **Datasets**: A través de la biblioteca `datasets`, Hugging Face facilita el acceso a conjuntos de datos comunes utilizados en NLP, lo que simplifica el proceso de entrenamiento y evaluación de modelos.
#
# ### **Usos Comunes de Hugging Face**
#
# Hugging Face y su biblioteca `transformers` se utilizan en una variedad de aplicaciones de NLP, incluyendo:
#
# - **Clasificación de Texto**: Identificación de sentimientos, categorización de documentos, detección de spam, etc.
# - **Generación de Texto**: Creación de texto coherente y relevante a partir de una entrada dada, como en los chatbots y asistentes virtuales.
# - **Traducción de Idiomas**: Conversión automática de texto de un idioma a otro.
# - **Resumen de Texto**: Reducción de largos documentos a sus puntos clave de manera concisa.
# - **Respuesta a Preguntas**: Extracción de respuestas precisas a preguntas formuladas en lenguaje natural a partir de un corpus de documentos.
#
# ### **Ejemplos de Uso**
#
# A continuación, se muestra un ejemplo simple de cómo usar un modelo preentrenado de Hugging Face para realizar análisis de sentimientos:

# %%
# %%capture
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu

# %%
from transformers import pipeline

# Cargar un pipeline preentrenado para análisis de sentimientos
classifier = pipeline('sentiment-analysis')

# Analizar el sentimiento de una muestra de texto
result = classifier("I love using Hugging Face models for NLP tasks!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# [{'label': 'POSITIVE', 'score': 0.9969214200973511}]

# %% [markdown]
# ## Procesamiento del Lenguaje Natural (NLP)
# El Procesamiento del Lenguaje Natural (NLP, por sus siglas en inglés) es una subdisciplina de la inteligencia artificial (IA) y la lingüística computacional que se centra en la interacción entre las computadoras y el lenguaje humano. El objetivo del NLP es permitir que las máquinas comprendan, interpreten, generen y respondan al lenguaje humano de manera que sea útil y natural.
#
# ###Aplicaciones del NLP
# 1. Clasificación de Texto:
#
# Descripción: Asignación de categorías a texto basado en su contenido.
# Ejemplo: Clasificar reseñas de productos como positivas o negativas.
#
# 2. Generación de Texto:
#
# Descripción: Creación automática de texto coherente y relevante.
# Ejemplo: Generar resúmenes de documentos o respuestas de chatbots.
#
# 3. Traducción Automática:
#
# Descripción: Conversión de texto de un idioma a otro.
# Ejemplo: Traducir un artículo de noticias del inglés al español.
# Reconocimiento de Entidades Nombradas (NER):
#
# Descripción: Identificación y categorización de entidades mencionadas en el texto (personas, lugares, organizaciones, etc.).
# Ejemplo: Extraer nombres de personajes y lugares de un artículo de noticias.
#
# 4. Análisis de Sentimientos:
#
# Descripción: Determinar la actitud o emoción expresada en un texto.
# Ejemplo: Analizar tuits para identificar si son positivos, negativos o neutrales.
#
# 5. Respuesta a Preguntas:
#
# Descripción: Proveer respuestas precisas a preguntas formuladas en lenguaje natural.
# Ejemplo: Un sistema que responde a la pregunta "¿Quién es el presidente de Francia?" con "Emmanuel Macron".

# %%
from datasets import Dataset

comments_dataset = Dataset.from_pandas(df)
comments_dataset
# Out:
# Dataset({
#     features: ['Titulo', 'Fecha', 'Autor', 'Contenido', 'Url'],
#     num_rows: 10
# })

# %%
comments_dataset['Contenido'][0].split()
# Out:
# ['Las',
#  'cifras',
#  'avalan',
#  'el',
#  'posicionamiento',
#  'de',
#  'Barranquilla',
#  'como',
#  'destino',
#  'para',
#  'viajes',
#  'de',
#  'negocios.',
#  'De',
#  'acuerdo',
#  'con',
#  'Erika',
#  'Grau,',
#  'gerente',
#  'de',
#  'turismo',
#  'de',
#  'negocios',
#  'de',
#  'ProBarranquilla,',
#  'desde',
#  'el',
#  'año',
#  '2017',
#  'la',
#  'ciudad',
#  'ha',
#  'captado',
#  'más',
#  'de',
#  '80',
#  'eventos,',
#  'los',
#  'cuales',
#  'han',
#  'movilizado',
#  'a',
#  'alrededor',
#  'de',
#  '75.000',
#  'visitantes.',
#  'Estos',
#  'eventos',
#  'han',
#  'generado',
#  'un',
#  'impacto',
#  'económico',
#  'superior',
#  'a',
#  'USD',
#  '60',
#  'millones,',
#  'producto',
#  'del',
#  'consumo',
#  'de',
#  'bienes',
#  'y',
#  'servicios',
#  'por',
#  'parte',
#  'de',
#  'los',
#  'asistentes.\u200b\u200bA',
#  'partir',
#  'de',
#  'esa',
#  'realidad,',
#  'Eugenia',
#  'Powell,',
#  'directora',
#  'de',
#  'Desarrollo',
#  'de',
#  'Negocios',
#  'de',
#  'PROMTUR',
#  'Panamá',
#  'invitó',
#  'a',
#  'los',
#  'gobiernos',
#  'a',
#  'seguir',
#  'apoyando',
#  'el',
#  'fortalecimiento',
#  'de',
#  'la',
#  'industria',
#  'de',
#  'reuniones',
#  'con',
#  'inversiónpública',
#  'en',
#  'la',
#  'promoción',
#  'del',
#  'turismo,',
#  'teniendo',
#  'claro',
#  'que',
#  'su',
#  'impacto',
#  'va',
#  'mucho',
#  'más',
#  'allá',
#  'de',
#  'lo',
#  'económico',
#  'porque',
#  'constituye',
#  'un',
#  'legado',
#  'que',
#  'mejora',
#  'el',
#  'bienestar',
#  'de',
#  'la',
#  'comunidad,',
#  'el',
#  'cual',
#  'es',
#  'difícil',
#  'de',
#  'medir,',
#  'pero',
#  'que',
#  'tiene',
#  'un',
#  'alto',
#  'contenido',
#  'social.(Puede',
#  'leer:',
#  'Día',
#  'Mundial',
#  'del',
#  'Medioambiente:',
#  'Barranquilla',
#  'sigue',
#  'celebrando',
#  'con',
#  'actividades',
#  'en',
#  'el',
#  'Gran',
#  'Malecón',
#  'y',
#  'la',
#  'Ciénaga',
#  'de',
#  'Mallorquín)Powell,',
#  'invitada',
#  'a',
#  'ExpoProBarranquilla,',
#  'puso',
#  'como',
#  'ejemplo',
#  'el',
#  'Plan',
#  'Maestro',
#  'de',
#  'Turismo',
#  'Sostenible',
#  'que',
#  'desarrolla',
#  'de',
#  'Panamá,',
#  'el',
#  'cual',
#  'está',
#  'dirigido',
#  'a',
#  'la',
#  'conservación',
#  'de',
#  'los',
#  'recursos',
#  'naturales',
#  'y',
#  'culturales',
#  'del',
#  'país,',
#  'priorizando',
#  'destinos',
#  'y',
#  'las',
#  'comunidades',
#  'con',
#  'más',
#  'necesidades,',
#  'buscando',
#  'a',
#  'los',
#  'turistas',
#  'conscientes',
#  'que',
#  'son',
#  'aquellos',
#  'que',
#  'viajan',
#  'a',
#  'los',
#  'lugares',
#  'para',
#  'conocerlos',
#  'y',
#  'disfrutarlos,',
#  'pero',
#  'también',
#  'para',
#  'mejorarlos',
#  'de',
#  'alguna',
#  'manera.',
#  'A',
#  'su',
#  'vez,',
#  'Samy',
#  'Bessudo,',
#  'presidente',
#  'de',
#  'Aviatur,',
#  'enfatizó',
#  'en',
#  'que',
#  '“claramente',
#  'Barranquilla',
#  'es',
#  'una',
#  'ciudad',
#  'turística.',
#  'Hace',
#  'unos',
#  'años',
#  'eso',
#  'no',
#  'era',
#  'pensable,',
#  'pero',
#  'las',
#  'cifras',
#  'de',
#  'hoy',
#  'lo',
#  'demuestran.',
#  'Hay',
#  'que',
#  'seguir',
#  'trabajando',
#  'y',
#  'hacerlo',
#  'bien”.De',
#  'acuerdo',
#  'con',
#  'el',
#  'empresario,',
#  'quienes',
#  'están',
#  'vinculados',
#  'a',
#  'esta',
#  'industria',
#  'deben',
#  'recordar',
#  'siempre',
#  'que',
#  'los',
#  'turistas',
#  'buscan',
#  'el',
#  'mejor',
#  'precio',
#  'y',
#  'la',
#  'más',
#  'rápida',
#  'conectividad,',
#  'lo',
#  'que',
#  'obliga',
#  'a',
#  'adaptarse',
#  'permanentemente',
#  'para',
#  'superar',
#  'ese',
#  'desafío',
#  'y',
#  'promover',
#  'el',
#  'turismo',
#  'responsable.',
#  '(Le',
#  'recomendamos:',
#  'Air-e',
#  'exhorta',
#  'al',
#  'Gobierno',
#  'y',
#  'la',
#  'Creg',
#  'a',
#  'lograr',
#  'acuerdos',
#  'para',
#  'reducir',
#  'un',
#  '10%',
#  'las',
#  'tarifas',
#  'de',
#  'energía',
#  'en',
#  'estratos',
#  '1,',
#  '2',
#  'y',
#  '3)“Colombia',
#  'es',
#  'uno',
#  'de',
#  'los',
#  'pocos',
#  'países',
#  'con',
#  'una',
#  'naturaleza',
#  'poderosamente',
#  'atractiva',
#  'para',
#  'el',
#  'turismo',
#  'consciente,',
#  'que',
#  'aún',
#  'quedan',
#  'por',
#  'conocerse.',
#  'Debemos',
#  'promovernos',
#  'basados',
#  'en',
#  'esa',
#  'fortaleza,',
#  'pero',
#  'con',
#  'el',
#  'debido',
#  'cuidado',
#  'para',
#  'garantizar',
#  'la',
#  'preservación',
#  'de',
#  'ese',
#  'recurso”,',
#  'puntualizó.',
#  'En',
#  'el',
#  'marco',
#  'del',
#  'encuentro',
#  'empresarial',
#  'que',
#  'se',
#  'llevó',
#  'a',
#  'cabo',
#  'en',
#  'días',
#  'pasados',
#  'en',
#  'la',
#  'ciudad,',
#  'la',
#  'Alcaldía',
#  'de',
#  'Barranquilla,',
#  'ProBarranquilla',
#  'y',
#  'Amazon',
#  'Web',
#  'Services',
#  'pusieron',
#  'en',
#  'marcha',
#  'el',
#  'programa',
#  'AWS',
#  'Skills',
#  'to',
#  'Jobs',
#  'Tech',
#  'Alliance,',
#  'con',
#  'el',
#  'objetivo',
#  'de',
#  'reunir',
#  'a',
#  'empleadores,',
#  'organizaciones',
#  'gubernamentales',
#  'y',
#  'de',
#  'desarrollo',
#  'de',
#  'la',
#  'fuerza',
#  'laboral,',
#  'y',
#  'lídereseducativos',
#  'para',
#  'cerrar',
#  'la',
#  'brecha',
#  'en',
#  'los',
#  'planes',
#  'de',
#  'estudio',
#  'de',
#  'universidades',
#  'e',
#  'instituciones',
#  'de',
#  'formación',
#  'tecnológica',
#  'y',
#  'establecer',
#  'una',
#  'ruta',
#  'de',
#  'empleabilidad',
#  'segura',
#  'para',
#  'los',
#  'jóvenes.']

# %%
comments_dataset = comments_dataset.map(
    lambda x: {"comment_length": len(x["Contenido"].split())} if x["Contenido"] is not None and "Contenido" in x else {"comment_length": 0}
)
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
comments_dataset = comments_dataset.filter(lambda x: x["comment_length"] > 15)
comments_dataset
# Out:
# Filter:   0%|          | 0/10 [00:00<?, ? examples/s]
# Dataset({
#     features: ['Titulo', 'Fecha', 'Autor', 'Contenido', 'Url', 'comment_length'],
#     num_rows: 10
# })

# %% [markdown]
# ### Tokenización
# La tokenización es un paso fundamental en el procesamiento del lenguaje natural (NLP) y el aprendizaje automático. Consiste en dividir un texto en unidades más pequeñas, llamadas "tokens". Estos tokens pueden ser palabras, subpalabras, caracteres o incluso grupos de palabras, dependiendo del tipo de tokenización que se aplique. El objetivo principal de la tokenización es transformar el texto en una forma que pueda ser entendida y procesada por algoritmos y modelos de aprendizaje automático.

# %%
def concatenate_text(examples):
    return {
        "text": examples["Titulo"]
        + " \n "
        + examples["Contenido"]

    }


comments_dataset = comments_dataset.map(concatenate_text)
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer, TFAutoModel

model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = TFAutoModel.from_pretrained(model_ckpt, from_pt=True)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFMPNetModel: ['embeddings.position_ids']
# - This IS expected if you are initializing TFMPNetModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFMPNetModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFMPNetModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMPNetModel for predictions without further training.

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

# %%
max_length = 512  # Límite máximo del modelo


# Función de tokenización y verificación de truncamiento
def get_embeddings(text_list):
    encoded_input = tokenizer(
        text_list, padding=True, truncation=True, max_length=max_length, return_tensors="tf"
    )
    truncated = [len(tokens) == max_length for tokens in encoded_input['input_ids']]
    encoded_input = {k: v for k, v in encoded_input.items()}
    model_output = model(**encoded_input)
    return cls_pooling(model_output), truncated

# %%
def map_embeddings(example):
    embeddings, truncated = get_embeddings([example["text"]])
    return {"embeddings": embeddings.numpy()[0], "truncated": truncated[0]}

# %%
embeddings_dataset = comments_dataset.map(map_embeddings)
embeddings_dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/tf_utils.py:465: UserWarning: `seed_generator` is deprecated and will be removed in a future version.
#   warnings.warn("`seed_generator` is deprecated and will be removed in a future version.", UserWarning)
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# Dataset({
#     features: ['Titulo', 'Fecha', 'Autor', 'Contenido', 'Url', 'comment_length', 'text', 'embeddings', 'truncated'],
#     num_rows: 10
# })

# %%
filtered_dataset = embedding.filter(lambda x: not x["truncated"])
filtered_dataset
# Out:
# Filter:   0%|          | 0/10 [00:00<?, ? examples/s]
# Dataset({
#     features: ['Titulo', 'Fecha', 'Autor', 'Contenido', 'Url', 'comment_length', 'text', 'embeddings', 'truncated'],
#     num_rows: 1
# })

# %% [markdown]
# ## FAISS: Facebook AI Similarity Search
# FAISS (Facebook AI Similarity Search) es una biblioteca de código abierto desarrollada por Facebook AI Research (FAIR) que permite la búsqueda rápida y eficiente de similitudes en grandes conjuntos de datos vectoriales. Es particularmente útil en aplicaciones de búsqueda y recuperación de información, como motores de búsqueda, sistemas de recomendación, y recuperación de imágenes.

# %%
embeddings_dataset.add_faiss_index(column="embeddings")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset({
#     features: ['Titulo', 'Fecha', 'Autor', 'Contenido', 'Url', 'comment_length', 'text', 'embeddings', 'truncated'],
#     num_rows: 10
# })

# %%
# Función para obtener el embedding de una pregunta
def get_question_embedding(question):
    embeddings, _ = get_embeddings([question])  # Ignora la información de truncamiento
    return embeddings.numpy()

# Obtener el embedding de la pregunta
question = "Que troncal esta en el norte"
question_embedding = get_question_embedding(question)
print(question_embedding.shape)
# Out:
# (1, 768)

# %%
# Obtener los ejemplos más cercanos
scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=10
)

# %%
samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores
samples_df.sort_values("scores", ascending=True, inplace=True)

# %%
for _, row in samples_df.iterrows():
    print(f"SCORE: {row.scores}")
    print(f"TITLE: {row.Titulo}")
    print(f"URL: {row.Url}")
    print("=" * 50)
    print()
# Out:
# SCORE: 32.07453155517578
# TITLE: Mujer terminó golpeada y sin pertenencias después de citarse con un hombre que conoció en internet: 'Me tuve que tirar por la ventana'
# URL: https://www.eltiempo.com/bogota/mujer-termino-secuestrada-y-robada-despues-de-encontrarse-con-un-hombre-que-conocio-en-app-de-citas-3350657
# ==================================================
#
# SCORE: 35.22445297241211
# TITLE: Fuad Char reveló cuáles serían los dos primeros refuerzos de Junior para la siguiente temporada
# URL: https://www.eltiempo.com/deportes/futbol-colombiano/fuad-char-revelo-cuales-serian-los-dos-primeros-refuerzos-de-junior-para-la-siguiente-temporada-3350664
# ==================================================
#
# SCORE: 35.52629470825195
# TITLE: Región metropolitana: municipio de Chía da un paso clave para ser el nuevo socio de Bogotá, Soacha y Cundinamarca; alcalde explica la decisión
# URL: https://www.eltiempo.com/bogota/region-metropolitana-chia-da-paso-clave-para-convertirse-en-nuevo-socio-de-bogota-soacha-y-cundinamarca-alcalde-explica-decision-3350639
# ==================================================
#
# SCORE: 35.60630798339844
# TITLE: EN VIVO | Movilidad en Bogotá: se reportan manifestaciones en la av. NQS, estación Universidad Nacional deja de operar
# URL: https://www.eltiempo.com/bogota/en-vivo-movilidad-bogota-asi-amanece-la-movilidad-en-la-capital-este-viernes-7-de-junio-3350343
# ==================================================
#
# SCORE: 35.84892272949219
# TITLE: Lo último: reportan una fuerte explosión en el corregimiento de Robles, en Jamundí
# URL: https://www.eltiempo.com/colombia/cali/lo-ultimo-reportan-una-fuerte-explosion-en-el-corregimiento-de-robles-en-jamundi-3350662
# ==================================================
#
# SCORE: 37.2702522277832
# TITLE: Al menos un estudiante muerto y otro herido tras un tiroteo en un campus universitario en Panamá
# URL: https://www.eltiempo.com/mundo/latinoamerica/al-menos-un-estudiante-muerto-en-un-tiroteo-en-un-campus-universitario-en-panama-3350669
# ==================================================
#
# SCORE: 39.147239685058594
# TITLE: Estos son los importantes negocios de 'Ceta' y ‘Valkiria’ ganadores del 'Desafío 2022'
# URL: https://www.eltiempo.com/cultura/gente/estos-son-los-importantes-negocios-de-ceta-y-valkiria-ganadores-de-desafio-2022-3350678
# ==================================================
#
# SCORE: 41.07806396484375
# TITLE: Urgente: escalada terrorista contra la Policía; explota carro bomba en Robles y atacan con drones el comando de la institución en Popayán
# URL: https://www.eltiempo.com/justicia/conflicto-y-narcotrafico/urgente-escalada-terrorista-contra-la-policia-explota-carro-bomba-en-robles-y-atacan-con-tatucos-el-comando-de-la-institucion-en-popayan-3350675
# ==================================================
#
# SCORE: 41.44049835205078
# TITLE: Chile estaría atravesando una crisis antes de la Copa América: el sueldo de Ricardo Gareca, embolatado
# URL: https://www.eltiempo.com/deportes/futbol-internacional/chile-estaria-atravesando-una-crisis-antes-de-la-copa-america-el-sueldo-de-ricardo-gareca-embolatado-3350681
# ==================================================
#
# SCORE: 44.4113655090332
# TITLE: Infraestructura de primer nivel y clima favorable posicionan a Barranquilla como destino de turismo de reuniones
# URL: https://www.eltiempo.com/colombia/barranquilla/infraestructura-de-primer-nivel-y-clima-favorable-posicionan-a-barranquilla-como-destino-de-turismo-de-reuniones-3350663
# ==================================================
